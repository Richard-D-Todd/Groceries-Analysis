# %% [markdown]
# ## Extracting Data from Email
#
# ### Extracting and seperating the HTML body and email headers

# %%
# Import libraries
import email
from email.policy import default
from requests_html import HTML
import pandas as pd
import datetime
import numpy as np
import os
import psycopg2
import sqlalchemy

# %%
# Open eml email file as an email.message type object
with open('Your updated ASDA Groceries order.eml', 'r') as file:
   
   msg = email.message_from_file(file, policy=default)

# %%
# Extract the parts of the message and enter it into a dictionary
body = msg.get_payload(decode=True)
dict = {'to': msg['to'], 'from': msg['from'], 'subject': msg['subject'], 'date': msg['date'], 'body': body}
print('To: {}'.format(msg['to']))
print('From: {}'.format(msg['from']))
print('Date: {}'.format(msg['date']))
print('Subject: {}'.format(msg['subject']))
# Out:
# To: "example@email.com" <example@email.com>
# From: ASDA Customer Services <home.shopping@asda.co.uk>
# Date: Thu, 26 Mar 2020 06:40:04 +0100
# Subject: Your updated ASDA Groceries order

# %% [markdown]
# ### Converting HTML body to text

# %%
#Grab the HTML from the body of the email and extract the table element
html = HTML(html=body)

match = html.find('tr')
print(match)
# Out:
# [<Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >]

# %%
#All the tr elements in match are the same
i=0
equiv = []
while i < len(match):
    equiv.append(str(match[0]) == str(match[i]))
    i += 1
print(equiv)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True]

# %% [markdown]
# ### Converting body to list and manipulating lists

# %%
# Get the content of the email body from the first tr element above. Then sperate into lines
content = match[0].text
lines = content.splitlines()

# %%
# List the content of the list lines with the index number
for i, line in enumerate(lines):
    print(i, line)
# Out:
# 0 Order Number:
# 1 012345678910
# 2 Delivery Date:
# 3 26 Mar 2020 11:00 AM-01:00 PM
# 4 Delivery Note
# 5 Hi Richard,
# 6
# 7 Your order has been picked and is being prepared for delivery. Your order details are listed below. Visit your order detail page for updates on your delivery time.
# 8
# 9 If you're unhappy with any of your products, simply hand them back to your driver for a full refund.
# 10
# 11
# 12
# 13 Order Details
# 14
# 15
# 16 Substitutes
# 17 Qty
# 18 Price
# 19 ASDA Simply Cook Smoked Crispy Bacon 60g
# 20 Substitute for 1 X ASDA Diced Pancetta Twin Pack 160g
# 21 1
# 22 £1.30
# 23 ASDA 2 Crisp Crumb Chunky Cod Fillets 350g
# 24 Substitute for 1 X Young's 6 Chunky Fish Fillets in Crispy Breadcrumbs 690g
# 25 1
# 26 £3.20
# 27 Yeo Valley Strawberry Yogurt 450g
# 28 Substitute for 1 X Arla Skyr Strawberry Yogurt 450g
# 29 1
# 30 £1.40
# 31 ASDA 18 Battered Chicken Breast Chunks 350g
# 32 Substitute for 1 X ASDA Crispy Chicken Breast Strips 400g
# 33 1
# 34 £2.50
# 35 New York Bakery Co The Original Plain Bagels 5pk
# 36 Substitute for 1 X ASDA Plain Bagels 4pk
# 37 1
# 38 £0.69
# 39 ASDA Creamy Tomato Pasta Bake 500g
# 40 Substitute for 1 X ASDA Tomato and Bacon Pasta Bake 480g
# 41 1
# 42 £0.75
# 43 ASDA Butcher's Selection 8 Pork Loin Steaks 800g
# 44 Substitute for 1 X ASDA Butcher's Selection Pork Boneless & Rindless Loin Joint 700g
# 45 1
# 46 £3.90
# 47 ASDA GS Honeydew Melon EACH
# 48 Substitute for 1 X ASDA Grower's Selection Cantaloupe Melon each
# 49 1
# 50 £1.69
# 51 ASDA Mexican Style Plain Tortillas 8pk
# 52 Substitute for 1 X ASDA 10 Mini Plain Tortillas 300g
# 53 1
# 54 £1.00
# 55
# 56
# 57 Unavailable
# 58 Qty
# 59 Price
# 60 ASDA Peppercorn Sauce 200g
# 61 1
# 62 £0.00
# 63 ASDA Fusilli 500g
# 64 3
# 65 £0.00
# 66 ASDA Conchiglie 500g
# 67 1
# 68 £0.00
# 69 ASDA 6 Medium Free Range Eggs 6pk
# 70 1
# 71 £0.00
# 72 George Home Plastic Food Storers 3x1l
# 73 1
# 74 £0.00
# 75
# 76
# 77 Ordered
# 78 Qty
# 79 Price
# 80 Chilled
# 81 ASDA Butcher's Selection Beef Mince (Typically Less Than 20% Fat) 500g
# 82
# 83 1
# 84 £1.59
# 85 ASDA Butcher's Selection Prime Beef Ribeye Steak 227g
# 86
# 87 2
# 88 £6.50
# 89 ASDA Butcher's Selection Lean Beef Mince (Typically Less Than 5% Fat) 500g
# 90
# 91 1
# 92 £2.97
# 93 ASDA Grower's Selection Carrots 500g
# 94
# 95 1
# 96 £0.33
# 97 ASDA Crispy Potato Slices 300g
# 98
# 99 1
# 100 £0.85
# 101 ASDA Butcher's Selection Chicken Breast Fillets 1kg
# 102
# 103 1
# 104 £5.19
# 105 Cadbury Pots of Joy Dairy Milk Chocolate Dessert 4x65g
# 106
# 107 2
# 108 £2.00
# 109 ASDA Thick Dry Cured Honey Roast Ham Slices 150g
# 110
# 111 1
# 112 £1.90
# 113 ASDA Simple to Cook Bourbon Beef Brisket 400g
# 114
# 115 1
# 116 £3.90
# 117 Arla Skyr Vanilla Yogurt 450g
# 118
# 119 1
# 120 £1.40
# 121 ASDA Grated Mozzarella Cheese 250g
# 122
# 123 1
# 124 £1.75
# 125 ASDA Butcher's Selection Diced Beef 475g
# 126
# 127 1
# 128 £3.80
# 129 ASDA Grated Four Cheese Blend 200g
# 130
# 131 1
# 132 £1.75
# 133 Products By Weight
# 134 ASDA Farm Stores White Potatoes 2kg
# 135
# 136 1
# 137 £1.00
# 138 Frozen
# 139 Aunt Bessie's 10 Dumplings 490g
# 140
# 141 1
# 142 £1.00
# 143 Richmond 20 Thick Frozen Pork Sausages 907g
# 144
# 145 1
# 146 £2.50
# 147 ASDA 4 Buttermilk Chicken Breast Fillet Burgers 400g
# 148
# 149 1
# 150 £2.50
# 151 Groceries, Health & Beauty and Household Items
# 152 Maltesers Bunnies Large Chocolate Easter Egg 265g
# 153
# 154 1
# 155 £4.00
# 156 Cadbury Dairy Milk Caramel Gift Boxed Giant Easter Egg 311g
# 157
# 158 1
# 159 £4.00
# 160 ASDA No Added Sugar Apple & Blackcurrant Squash 1.5l
# 161
# 162 1
# 163 £0.95
# 164 Pepsi Max Raspberry Cans 8x330
# 165
# 166 1
# 167 £3.75
# 168 Pepsi Max Cherry Cans 8x330
# 169
# 170 1
# 171 £3.75
# 172 ASDA Butter Chicken Curry Sauce 495g
# 173
# 174 1
# 175 £0.79
# 176 ASDA Grower's Selection Baby Potatoes 1kg
# 177
# 178 1
# 179 £0.80
# 180 ASDA Mint Sauce 280g
# 181
# 182 1
# 183 £0.83
# 184 Weetabix Crispy Minis Chocolate Chip 600g
# 185
# 186 1
# 187 £2.98
# 188 ASDA Bolognese Pasta Sauce 720g
# 189
# 190 1
# 191 £0.84
# 192 Patak's Korma Curry Sauce 450g
# 193
# 194 1
# 195 £1.00
# 196 ASDA Taco Seasoning 35g
# 197
# 198 2
# 199 £1.24
# 200 ASDA Taco Shells 150g
# 201
# 202 1
# 203 £1.30
# 204 ASDA Jam & Creams 150g
# 205
# 206 1
# 207 £0.45
# 208 ASDA Extra Special Hand Finished Salted Caramel & Chocolate Cake each
# 209
# 210 1
# 211 £1.85
# 212 Kellogg's Coco Pops 480g
# 213
# 214 1
# 215 £2.89
# 216
# 217
# 218 Multibuy Savings
# 219 Savings
# 220 Easter Eggs - 2 for ������7.00
# 221 -£1.0
# 222 CEREALS - 2 FOR ������4.00
# 223 -£1.87
# 224 SLICED AND GRATED CHEESE - 2 FOR ������3
# 225 -£0.5
# 226 BIG POT YOGURTS - 2 FOR ������2.00
# 227 -£0.8
# 228 FRESH MEAT - 3 FOR ������10
# 229 -£2.5
# 230
# 231
# 232 Subtotal*
# 233 Pick and Pack
# 234 Minimum basket charge
# 235 eVouchers
# 236 Multibuy Savings
# 237 £89.68
# 238 £0.00
# 239 £0.00
# 240 - £0.00
# 241 - £6.67
# 242 Total
# 243 £83.01
# 244 * Please note: for items sold by weight, the exact price may vary depending on the weight of items available.
# 245 123 Fake Street, City, GB
# 246 26 Mar 2020 11:00 AM-01:00 PM
# 247
# 248
# 249 Regards,
# 250 ASDA Online Groceries Team
# 251 Contact Us
# 252 FAQs
# 253
# 254 CHALLENGE 25
# 255 As part of the Challenge 25 initiative we may need to check your date of Birth when we deliver to your address. As our minimum order age is 18, this applies to all online grocery orders, regardless of whether age restricted products are present in the order.
# 256
# 257 Please do not reply to this email.
# 258 If you'd like to get in touch, please call our customer services team on 0800 952 0101. Calls are free from a BT landline, calls from other service providers and mobile networks may vary. Lines are open Monday to Saturday 07:00 - 23:00 and Sunday 08:00 - 22:00.
# 259
# 260 This email and any files transmitted with it are confidential and intended solely for the individual or entity to whom they are addressed. If you have received this email in error please accept our apologies & destroy it immediately.
# 261
# 262 This is a service message from Asda Stores Ltd, Registered in England No. 464777.
# 263 Registered Office: Asda House, Southbank, Great Wilson Street, Leeds LS11 5AD
# 264 ASDA 2018
# 265 Terms & Conditions ⋅ Privacy & Cookies Policy

# %%
# Extract the order number, delivery date, subtotal and total
order_number = lines[1]
delivery_date_str = lines[3]

# The value of the order total is on the line below the total header
total_str = lines[lines.index('Total') + 1]

# The value of the subtotal is 5 lines below the subtotal header
subtotal_str = lines[lines.index('Subtotal*') + 5]

print('Order Number :', order_number, type(order_number))
print('Delivery Date:', delivery_date_str, type(delivery_date_str))
print('Subtotal is  :', subtotal_str, type(subtotal_str))
print('Total is     :', total_str, type(total_str))
# Out:
# Order Number : 012345678910 <class 'str'>
# Delivery Date: 26 Mar 2020 11:00 AM-01:00 PM <class 'str'>
# Subtotal is  : £89.68 <class 'str'>
# Total is     : £83.01 <class 'str'>

# %%
# Converting strings above to other data types

#Convert delivery date string to date object, by slicing to just date part and then converting
delivery_date_str = delivery_date_str[0:11]
print(delivery_date_str)
delivery_date = datetime.datetime.strptime(delivery_date_str, '%d %b %Y').date()
print('Delivery Date:', delivery_date, type(delivery_date))

#Converting Subtotal and total to float
def convert_str_price_to_float(x):
    x = x[1:]
    return float(x)

subtotal = convert_str_price_to_float(subtotal_str)
print('Subtotal     :', subtotal, type(subtotal))

total = convert_str_price_to_float(total_str)
print('Total        :', total, type(total))
# Out:
# 26 Mar 2020
# Delivery Date: 2020-03-26 <class 'datetime.date'>
# Subtotal     : 89.68 <class 'float'>
# Total        : 83.01 <class 'float'>

# %%
# Selecting the block of text after the Substitutes header

# Start_substitutes finds the index of the line containing the Substitutes header
start_substitutes = lines.index('Substitutes')

# We skip the qty and price labels by starting the loop 3 lines below the substitutes header
# The loop ends before the first empty space
i = start_substitutes + 3
while len(lines[i]) > 0 :
    print(lines[i])
    i += 1
# Out:
# ASDA Simply Cook Smoked Crispy Bacon 60g
# Substitute for 1 X ASDA Diced Pancetta Twin Pack 160g
# 1
# £1.30
# ASDA 2 Crisp Crumb Chunky Cod Fillets 350g
# Substitute for 1 X Young's 6 Chunky Fish Fillets in Crispy Breadcrumbs 690g
# 1
# £3.20
# Yeo Valley Strawberry Yogurt 450g
# Substitute for 1 X Arla Skyr Strawberry Yogurt 450g
# 1
# £1.40
# ASDA 18 Battered Chicken Breast Chunks 350g
# Substitute for 1 X ASDA Crispy Chicken Breast Strips 400g
# 1
# £2.50
# New York Bakery Co The Original Plain Bagels 5pk
# Substitute for 1 X ASDA Plain Bagels 4pk
# 1
# £0.69
# ASDA Creamy Tomato Pasta Bake 500g
# Substitute for 1 X ASDA Tomato and Bacon Pasta Bake 480g
# 1
# £0.75
# ASDA Butcher's Selection 8 Pork Loin Steaks 800g
# Substitute for 1 X ASDA Butcher's Selection Pork Boneless & Rindless Loin Joint 700g
# 1
# £3.90
# ASDA GS Honeydew Melon EACH
# Substitute for 1 X ASDA Grower's Selection Cantaloupe Melon each
# 1
# £1.69
# ASDA Mexican Style Plain Tortillas 8pk
# Substitute for 1 X ASDA 10 Mini Plain Tortillas 300g
# 1
# £1.00

# %%
# This groups the lines into a new substitutes list which is made up of a tuple of 4 elements
i = start_substitutes + 3
substitutes = []
while len(lines[i]) > 0 :
    substitutes.append((lines[i], lines[i + 1][19:], lines[i + 2], lines[i + 3]))
    i += 4

# %%
print(substitutes)
# Out:
# [('ASDA Simply Cook Smoked Crispy Bacon 60g', 'ASDA Diced Pancetta Twin Pack 160g', '1', '£1.30'), ('ASDA 2 Crisp Crumb Chunky Cod Fillets 350g', "Young's 6 Chunky Fish Fillets in Crispy Breadcrumbs 690g", '1', '£3.20'), ('Yeo Valley Strawberry Yogurt 450g', 'Arla Skyr Strawberry Yogurt 450g', '1', '£1.40'), ('ASDA 18 Battered Chicken Breast Chunks 350g', 'ASDA Crispy Chicken Breast Strips 400g', '1', '£2.50'), ('New York Bakery Co The Original Plain Bagels 5pk', 'ASDA Plain Bagels 4pk', '1', '£0.69'), ('ASDA Creamy Tomato Pasta Bake 500g', 'ASDA Tomato and Bacon Pasta Bake 480g', '1', '£0.75'), ("ASDA Butcher's Selection 8 Pork Loin Steaks 800g", "ASDA Butcher's Selection Pork Boneless & Rindless Loin Joint 700g", '1', '£3.90'), ('ASDA GS Honeydew Melon EACH', "ASDA Grower's Selection Cantaloupe Melon each", '1', '£1.69'), ('ASDA Mexican Style Plain Tortillas 8pk', 'ASDA 10 Mini Plain Tortillas 300g', '1', '£1.00')]

# %%
# finds unavailable section
start_unavailable = lines.index('Unavailable')

i = start_unavailable + 3
while len(lines[i]) > 0 :
    print(lines[i])
    i += 1
# Out:
# ASDA Peppercorn Sauce 200g
# 1
# £0.00
# ASDA Fusilli 500g
# 3
# £0.00
# ASDA Conchiglie 500g
# 1
# £0.00
# ASDA 6 Medium Free Range Eggs 6pk
# 1
# £0.00
# George Home Plastic Food Storers 3x1l
# 1
# £0.00

# %%
# This packs the unavailable section into a list of tuples
i = start_unavailable + 3
unavailable = []
while len(lines[i]) > 0 :
    unavailable.append((lines[i], lines[i + 1], lines[i + 2]))
    i += 3

# %%
# We can find the start and end of the ordered section
start_ordered = lines.index('Ordered')

end_ordered = lines.index('Multibuy Savings')

i = start_ordered + 3
while i < end_ordered :
    print(lines[i])
    i += 1
# Out:
# Chilled
# ASDA Butcher's Selection Beef Mince (Typically Less Than 20% Fat) 500g
#
# 1
# £1.59
# ASDA Butcher's Selection Prime Beef Ribeye Steak 227g
#
# 2
# £6.50
# ASDA Butcher's Selection Lean Beef Mince (Typically Less Than 5% Fat) 500g
#
# 1
# £2.97
# ASDA Grower's Selection Carrots 500g
#
# 1
# £0.33
# ASDA Crispy Potato Slices 300g
#
# 1
# £0.85
# ASDA Butcher's Selection Chicken Breast Fillets 1kg
#
# 1
# £5.19
# Cadbury Pots of Joy Dairy Milk Chocolate Dessert 4x65g
#
# 2
# £2.00
# ASDA Thick Dry Cured Honey Roast Ham Slices 150g
#
# 1
# £1.90
# ASDA Simple to Cook Bourbon Beef Brisket 400g
#
# 1
# £3.90
# Arla Skyr Vanilla Yogurt 450g
#
# 1
# £1.40
# ASDA Grated Mozzarella Cheese 250g
#
# 1
# £1.75
# ASDA Butcher's Selection Diced Beef 475g
#
# 1
# £3.80
# ASDA Grated Four Cheese Blend 200g
#
# 1
# £1.75
# Products By Weight
# ASDA Farm Stores White Potatoes 2kg
#
# 1
# £1.00
# Frozen
# Aunt Bessie's 10 Dumplings 490g
#
# 1
# £1.00
# Richmond 20 Thick Frozen Pork Sausages 907g
#
# 1
# £2.50
# ASDA 4 Buttermilk Chicken Breast Fillet Burgers 400g
#
# 1
# £2.50
# Groceries, Health & Beauty and Household Items
# Maltesers Bunnies Large Chocolate Easter Egg 265g
#
# 1
# £4.00
# Cadbury Dairy Milk Caramel Gift Boxed Giant Easter Egg 311g
#
# 1
# £4.00
# ASDA No Added Sugar Apple & Blackcurrant Squash 1.5l
#
# 1
# £0.95
# Pepsi Max Raspberry Cans 8x330
#
# 1
# £3.75
# Pepsi Max Cherry Cans 8x330
#
# 1
# £3.75
# ASDA Butter Chicken Curry Sauce 495g
#
# 1
# £0.79
# ASDA Grower's Selection Baby Potatoes 1kg
#
# 1
# £0.80
# ASDA Mint Sauce 280g
#
# 1
# £0.83
# Weetabix Crispy Minis Chocolate Chip 600g
#
# 1
# £2.98
# ASDA Bolognese Pasta Sauce 720g
#
# 1
# £0.84
# Patak's Korma Curry Sauce 450g
#
# 1
# £1.00
# ASDA Taco Seasoning 35g
#
# 2
# £1.24
# ASDA Taco Shells 150g
#
# 1
# £1.30
# ASDA Jam & Creams 150g
#
# 1
# £0.45
# ASDA Extra Special Hand Finished Salted Caramel & Chocolate Cake each
#
# 1
# £1.85
# Kellogg's Coco Pops 480g
#
# 1
# £2.89

# %%
# Creating a list for the ordered section
i = start_ordered + 3
ordered = []
while i < end_ordered :
    ordered.append(lines[i])
    i += 1

# %%
# Remove blank list elements and category headings

def remove_blank_and_headings(element):
    remove_list = ['Quantity', 'Price', 'Fresh', 'Fridge', 'Freezer', 'Chilled', 'Products By Weight', 'Frozen', 'Groceries, Health & Beauty and Household Items', 'Others', 'Other', None]
    if element in remove_list:
        return False
    else:
        return element
    
ordered = list(filter(remove_blank_and_headings, ordered))

# %%
# Create a list of tuples for the ordered items
i = 0
ordered_clean = []
print(len(ordered))

while i < len(ordered) :
    ordered_clean.append((ordered[i], ordered[i + 1], ordered[i + 2]))
    i += 3
    
print(ordered_clean)
# Out:
# 99
# [("ASDA Butcher's Selection Beef Mince (Typically Less Than 20% Fat) 500g", '1', '£1.59'), ("ASDA Butcher's Selection Prime Beef Ribeye Steak 227g", '2', '£6.50'), ("ASDA Butcher's Selection Lean Beef Mince (Typically Less Than 5% Fat) 500g", '1', '£2.97'), ("ASDA Grower's Selection Carrots 500g", '1', '£0.33'), ('ASDA Crispy Potato Slices 300g', '1', '£0.85'), ("ASDA Butcher's Selection Chicken Breast Fillets 1kg", '1', '£5.19'), ('Cadbury Pots of Joy Dairy Milk Chocolate Dessert 4x65g', '2', '£2.00'), ('ASDA Thick Dry Cured Honey Roast Ham Slices 150g', '1', '£1.90'), ('ASDA Simple to Cook Bourbon Beef Brisket 400g', '1', '£3.90'), ('Arla Skyr Vanilla Yogurt 450g', '1', '£1.40'), ('ASDA Grated Mozzarella Cheese 250g', '1', '£1.75'), ("ASDA Butcher's Selection Diced Beef 475g", '1', '£3.80'), ('ASDA Grated Four Cheese Blend 200g', '1', '£1.75'), ('ASDA Farm Stores White Potatoes 2kg', '1', '£1.00'), ("Aunt Bessie's 10 Dumplings 490g", '1', '£1.00'), ('Richmond 20 Thick Frozen Pork Sausages 907g', '1', '£2.50'), ('ASDA 4 Buttermilk Chicken Breast Fillet Burgers 400g', '1', '£2.50'), ('Maltesers Bunnies Large Chocolate Easter Egg 265g', '1', '£4.00'), ('Cadbury Dairy Milk Caramel Gift Boxed Giant Easter Egg 311g', '1', '£4.00'), ('ASDA No Added Sugar Apple & Blackcurrant Squash 1.5l', '1', '£0.95'), ('Pepsi Max Raspberry Cans 8x330', '1', '£3.75'), ('Pepsi Max Cherry Cans 8x330', '1', '£3.75'), ('ASDA Butter Chicken Curry Sauce 495g', '1', '£0.79'), ("ASDA Grower's Selection Baby Potatoes 1kg", '1', '£0.80'), ('ASDA Mint Sauce 280g', '1', '£0.83'), ('Weetabix Crispy Minis Chocolate Chip 600g', '1', '£2.98'), ('ASDA Bolognese Pasta Sauce 720g', '1', '£0.84'), ("Patak's Korma Curry Sauce 450g", '1', '£1.00'), ('ASDA Taco Seasoning 35g', '2', '£1.24'), ('ASDA Taco Shells 150g', '1', '£1.30'), ('ASDA Jam & Creams 150g', '1', '£0.45'), ('ASDA Extra Special Hand Finished Salted Caramel & Chocolate Cake each', '1', '£1.85'), ("Kellogg's Coco Pops 480g", '1', '£2.89')]

# %% [markdown]
# ### What I have so far
#
# So far I have several pieces of information directly from the email metadata:
# 1. Recipient email address
# 2. Sender email address
# 3. Subject line
# 4. Date email was sent
#
# Since these are going to remain constant these are not too useful. I also have the date the email was sent.
#
# I converted the HTML body of the email to text. Intially I wanted to parse the HTML to extract the data straight from the HTML body of the email. I found this dificult as when trying to access the tr and td elements of the HTML I was getting all of the body text instead of individual cells. Therefore I decided to manipulate the body of the email by splitting each line down into an element of a list.
#
# From this I have several lists of tuples for each subsection of the email along with a few intital values extract directly from the master list by knowing the index of the line in the list.
#
# Extract directly:
# 1. Total Cost as a string value
# 2. Subtotal as a string value
# 3. Order number as a string value
#
# Lists of tuples:
# 1. The substitutions sent to replace unavailable items
# 2. The unavailable items that couldn't be replaced, and so were removed from the order
# 3. The items that were delivered as ordered

# %% [markdown]
# ## Manipulating Data
#
# ### Converting lists to Pandas DataFrames

# %%
# Create substitutions dataframe
df_subs = pd.DataFrame(substitutes, columns = ['item', 'substituting', 'quantity', 'price'])
df_subs.head()
# Out:
#                                                item  \
# 0          ASDA Simply Cook Smoked Crispy Bacon 60g
# 1        ASDA 2 Crisp Crumb Chunky Cod Fillets 350g
# 2                 Yeo Valley Strawberry Yogurt 450g
# 3       ASDA 18 Battered Chicken Breast Chunks 350g
# 4  New York Bakery Co The Original Plain Bagels 5pk
#
#                                         substituting quantity  price
# 0                 ASDA Diced Pancetta Twin Pack 160g        1  £1.30
# 1  Young's 6 Chunky Fish Fillets in Crispy Breadc...        1  £3.20
# 2                   Arla Skyr Strawberry Yogurt 450g        1  £1.40
# 3             ASDA Crispy Chicken Breast Strips 400g        1  £2.50
# 4                              ASDA Plain Bagels 4pk        1  £0.69

# %%
# Creating Unavailable items dataframe
df_unavail = pd.DataFrame(unavailable, columns = ['item', 'quantity', 'price'])
df_unavail.head()
# Out:
#                                     item quantity  price
# 0             ASDA Peppercorn Sauce 200g        1  £0.00
# 1                      ASDA Fusilli 500g        3  £0.00
# 2                   ASDA Conchiglie 500g        1  £0.00
# 3      ASDA 6 Medium Free Range Eggs 6pk        1  £0.00
# 4  George Home Plastic Food Storers 3x1l        1  £0.00

# %%
# Creating ordered items dataframe
df_ordered = pd.DataFrame(ordered_clean, columns = ['item', 'quantity', 'price'])
df_ordered.head()
# Out:
#                                                 item quantity  price
# 0  ASDA Butcher's Selection Beef Mince (Typically...        1  £1.59
# 1  ASDA Butcher's Selection Prime Beef Ribeye Ste...        2  £6.50
# 2  ASDA Butcher's Selection Lean Beef Mince (Typi...        1  £2.97
# 3               ASDA Grower's Selection Carrots 500g        1  £0.33
# 4                     ASDA Crispy Potato Slices 300g        1  £0.85

# %%
# Creating Dataframe for the order number, delivery date, subtotal and total
order_dict = {'order_number': order_number,'delivery_date': delivery_date, 'subtotal': subtotal, 'total': total}

df_order_details = pd.DataFrame.from_dict([order_dict])
df_order_details.head()
# Out:
#    order_number delivery_date  subtotal  total
# 0  012345678910    2020-03-26     89.68  83.01

# %% [markdown]
# ### What I want the data to look like
#
# I would like to end up with three tables:
# 1. Table with the ordered items and substitutions. This will list the items that were actually delivered, the price before promotions, the quanitity and the unit price. There will also be a column with the Order Number. This will eventually act as a foreign key so that the items can be linked to an order. The column headers will be as below:
#
# order_number|item     |substitution |substituting  |price|quantity|unit_price
# ------------|---------|-------------|--------------|-----|--------|---
# 12345       |Item Name|1 or 0       |Item replacing|x.xx |y       |x.xx/y
#
#     The order number will come from the order_number variable calculated previously. If the record is a substitution a value      of True will be in the Subsitution column and the item it is a substituting will be in the substituting column. The Unit        Price coulmn will be calculated as Price/Quantity.
#
# 2. The second table will be unavailable products and will look like below:
#
# order_number|item|quantity
# ---|---|---
#
# 3. The third table will be the order details column and will look like below:
#
# order_number|delivery_date|subtotal|total|
# ------------|-------------|--------|-----|

# %% [markdown]
# ### Manipulating the Substitution DataFrame
# The Substitutions dataframe currently looks like this:

# %%
df_subs.head()
# Out:
#                                                item  \
# 0          ASDA Simply Cook Smoked Crispy Bacon 60g
# 1        ASDA 2 Crisp Crumb Chunky Cod Fillets 350g
# 2                 Yeo Valley Strawberry Yogurt 450g
# 3       ASDA 18 Battered Chicken Breast Chunks 350g
# 4  New York Bakery Co The Original Plain Bagels 5pk
#
#                                         substituting quantity  price
# 0                 ASDA Diced Pancetta Twin Pack 160g        1  £1.30
# 1  Young's 6 Chunky Fish Fillets in Crispy Breadc...        1  £3.20
# 2                   Arla Skyr Strawberry Yogurt 450g        1  £1.40
# 3             ASDA Crispy Chicken Breast Strips 400g        1  £2.50
# 4                              ASDA Plain Bagels 4pk        1  £0.69

# %% [markdown]
# List of tasks:
# 1. Append order number to start of dataframe.
# 2. Add a Substitution column with a value of True.
# 3. Swap position of Price and Quantity columns. Convert them from strings to numbers.
# 4. Convert Quantity column to int data type.
# 5. Convert Price column to a float.
# 6. Unit price by calculating Price/Quantity.

# %%
# Swap Price and quantity columns
col_titles = ['item', 'substituting', 'price', 'quantity']
df_subs = df_subs.reindex(columns=col_titles)

# %%
# Insert Order Number Column
def insert_order_num_col(df):
    df.insert(0, 'order_number', order_number)
    
insert_order_num_col(df_subs)

# %%
df_subs.head()
# Out:
#    order_number                                              item  \
# 0  012345678910          ASDA Simply Cook Smoked Crispy Bacon 60g
# 1  012345678910        ASDA 2 Crisp Crumb Chunky Cod Fillets 350g
# 2  012345678910                 Yeo Valley Strawberry Yogurt 450g
# 3  012345678910       ASDA 18 Battered Chicken Breast Chunks 350g
# 4  012345678910  New York Bakery Co The Original Plain Bagels 5pk
#
#                                         substituting  price quantity
# 0                 ASDA Diced Pancetta Twin Pack 160g  £1.30        1
# 1  Young's 6 Chunky Fish Fillets in Crispy Breadc...  £3.20        1
# 2                   Arla Skyr Strawberry Yogurt 450g  £1.40        1
# 3             ASDA Crispy Chicken Breast Strips 400g  £2.50        1
# 4                              ASDA Plain Bagels 4pk  £0.69        1

# %%
# define function to convert price from email to a float
def convert_price_col(df, col_name):
    """
    This function converts a string price column that starts with a £ sign to a column with type float64.
    Param 1: df object
    Param 2: Column name with quotes
        """
    df[col_name] = df[col_name].str[1:]
    df[col_name] = df[col_name].apply(pd.to_numeric)
    
convert_price_col(df_subs, 'price')

# %%
# Convert quantity to a integer
df_subs['quantity'] = df_subs['quantity'].astype('int', errors='ignore')

# %%
df_subs.dtypes
# Out:
# order_number     object
# item             object
# substituting     object
# price           float64
# quantity          int32
# dtype: object

# %%
# Calculate Unit Price Column
df_subs['unit_price'] = df_subs['price'] / df_subs['quantity']

# %%
df_subs
# Out:
#    order_number                                              item  \
# 0  012345678910          ASDA Simply Cook Smoked Crispy Bacon 60g
# 1  012345678910        ASDA 2 Crisp Crumb Chunky Cod Fillets 350g
# 2  012345678910                 Yeo Valley Strawberry Yogurt 450g
# 3  012345678910       ASDA 18 Battered Chicken Breast Chunks 350g
# 4  012345678910  New York Bakery Co The Original Plain Bagels 5pk
# 5  012345678910                ASDA Creamy Tomato Pasta Bake 500g
# 6  012345678910  ASDA Butcher's Selection 8 Pork Loin Steaks 800g
# 7  012345678910                       ASDA GS Honeydew Melon EACH
# 8  012345678910            ASDA Mexican Style Plain Tortillas 8pk
#
#                                         substituting  price  quantity  \
# 0                 ASDA Diced Pancetta Twin Pack 160g   1.30         1
# 1  Young's 6 Chunky Fish Fillets in Crispy Breadc...   3.20         1
# 2                   Arla Skyr Strawberry Yogurt 450g   1.40         1
# 3             ASDA Crispy Chicken Breast Strips 400g   2.50         1
# 4                              ASDA Plain Bagels 4pk   0.69         1
# 5              ASDA Tomato and Bacon Pasta Bake 480g   0.75         1
# 6  ASDA Butcher's Selection Pork Boneless & Rindl...   3.90         1
# 7      ASDA Grower's Selection Cantaloupe Melon each   1.69         1
# 8                  ASDA 10 Mini Plain Tortillas 300g   1.00         1
#
#    unit_price
# 0        1.30
# 1        3.20
# 2        1.40
# 3        2.50
# 4        0.69
# 5        0.75
# 6        3.90
# 7        1.69
# 8        1.00

# %%
df_subs.insert(2, 'substitution', True)

# %%
df_subs.head()
# Out:
#    order_number                                              item  \
# 0  012345678910          ASDA Simply Cook Smoked Crispy Bacon 60g
# 1  012345678910        ASDA 2 Crisp Crumb Chunky Cod Fillets 350g
# 2  012345678910                 Yeo Valley Strawberry Yogurt 450g
# 3  012345678910       ASDA 18 Battered Chicken Breast Chunks 350g
# 4  012345678910  New York Bakery Co The Original Plain Bagels 5pk
#
#    substitution                                       substituting  price  \
# 0          True                 ASDA Diced Pancetta Twin Pack 160g   1.30
# 1          True  Young's 6 Chunky Fish Fillets in Crispy Breadc...   3.20
# 2          True                   Arla Skyr Strawberry Yogurt 450g   1.40
# 3          True             ASDA Crispy Chicken Breast Strips 400g   2.50
# 4          True                              ASDA Plain Bagels 4pk   0.69
#
#    quantity  unit_price
# 0         1        1.30
# 1         1        3.20
# 2         1        1.40
# 3         1        2.50
# 4         1        0.69

# %%
df_subs.dtypes
# Out:
# order_number     object
# item             object
# substitution       bool
# substituting     object
# price           float64
# quantity          int32
# unit_price      float64
# dtype: object

# %% [markdown]
# ### Manipulating the ordered DataFrame
# The ordered dataframe currently looks like:

# %%
df_ordered.head()
# Out:
#                                                 item quantity  price
# 0  ASDA Butcher's Selection Beef Mince (Typically...        1  £1.59
# 1  ASDA Butcher's Selection Prime Beef Ribeye Ste...        2  £6.50
# 2  ASDA Butcher's Selection Lean Beef Mince (Typi...        1  £2.97
# 3               ASDA Grower's Selection Carrots 500g        1  £0.33
# 4                     ASDA Crispy Potato Slices 300g        1  £0.85

# %%
# Swap price and quantity columns
col_titles_unavail = ['item', 'price', 'quantity']
df_ordered = df_ordered.reindex(columns=col_titles_unavail)
df_ordered.head()
# Out:
#                                                 item  price quantity
# 0  ASDA Butcher's Selection Beef Mince (Typically...  £1.59        1
# 1  ASDA Butcher's Selection Prime Beef Ribeye Ste...  £6.50        2
# 2  ASDA Butcher's Selection Lean Beef Mince (Typi...  £2.97        1
# 3               ASDA Grower's Selection Carrots 500g  £0.33        1
# 4                     ASDA Crispy Potato Slices 300g  £0.85        1

# %%
# Insert order number column
insert_order_num_col(df_ordered)
df_ordered.head()
# Out:
#    order_number                                               item  price  \
# 0  012345678910  ASDA Butcher's Selection Beef Mince (Typically...  £1.59
# 1  012345678910  ASDA Butcher's Selection Prime Beef Ribeye Ste...  £6.50
# 2  012345678910  ASDA Butcher's Selection Lean Beef Mince (Typi...  £2.97
# 3  012345678910               ASDA Grower's Selection Carrots 500g  £0.33
# 4  012345678910                     ASDA Crispy Potato Slices 300g  £0.85
#
#   quantity
# 0        1
# 1        2
# 2        1
# 3        1
# 4        1

# %%
# Insert substitution column
df_ordered.insert(2, 'substitution', False)
df_ordered.head()
# Out:
#    order_number                                               item  \
# 0  012345678910  ASDA Butcher's Selection Beef Mince (Typically...
# 1  012345678910  ASDA Butcher's Selection Prime Beef Ribeye Ste...
# 2  012345678910  ASDA Butcher's Selection Lean Beef Mince (Typi...
# 3  012345678910               ASDA Grower's Selection Carrots 500g
# 4  012345678910                     ASDA Crispy Potato Slices 300g
#
#    substitution  price quantity
# 0         False  £1.59        1
# 1         False  £6.50        2
# 2         False  £2.97        1
# 3         False  £0.33        1
# 4         False  £0.85        1

# %%
# Insert Substituting column
df_ordered.insert(3, 'substituting', 'None')
df_ordered.head()
# Out:
#    order_number                                               item  \
# 0  012345678910  ASDA Butcher's Selection Beef Mince (Typically...
# 1  012345678910  ASDA Butcher's Selection Prime Beef Ribeye Ste...
# 2  012345678910  ASDA Butcher's Selection Lean Beef Mince (Typi...
# 3  012345678910               ASDA Grower's Selection Carrots 500g
# 4  012345678910                     ASDA Crispy Potato Slices 300g
#
#    substitution substituting  price quantity
# 0         False         None  £1.59        1
# 1         False         None  £6.50        2
# 2         False         None  £2.97        1
# 3         False         None  £0.33        1
# 4         False         None  £0.85        1

# %%
# Convert Quantity to integer
df_ordered['quantity'] = df_ordered['quantity'].astype('int', errors='ignore')
df_ordered.head()
# Out:
#    order_number                                               item  \
# 0  012345678910  ASDA Butcher's Selection Beef Mince (Typically...
# 1  012345678910  ASDA Butcher's Selection Prime Beef Ribeye Ste...
# 2  012345678910  ASDA Butcher's Selection Lean Beef Mince (Typi...
# 3  012345678910               ASDA Grower's Selection Carrots 500g
# 4  012345678910                     ASDA Crispy Potato Slices 300g
#
#    substitution substituting  price  quantity
# 0         False         None  £1.59         1
# 1         False         None  £6.50         2
# 2         False         None  £2.97         1
# 3         False         None  £0.33         1
# 4         False         None  £0.85         1

# %%
# Convert price column to float
convert_price_col(df_ordered, 'price')
df_ordered.head()
# Out:
#    order_number                                               item  \
# 0  012345678910  ASDA Butcher's Selection Beef Mince (Typically...
# 1  012345678910  ASDA Butcher's Selection Prime Beef Ribeye Ste...
# 2  012345678910  ASDA Butcher's Selection Lean Beef Mince (Typi...
# 3  012345678910               ASDA Grower's Selection Carrots 500g
# 4  012345678910                     ASDA Crispy Potato Slices 300g
#
#    substitution substituting  price  quantity
# 0         False         None   1.59         1
# 1         False         None   6.50         2
# 2         False         None   2.97         1
# 3         False         None   0.33         1
# 4         False         None   0.85         1

# %%
# Calculate unit price
df_ordered['unit_price'] = df_ordered['price'] / df_ordered['quantity']

# %%
df_ordered.head()
# Out:
#    order_number                                               item  \
# 0  012345678910  ASDA Butcher's Selection Beef Mince (Typically...
# 1  012345678910  ASDA Butcher's Selection Prime Beef Ribeye Ste...
# 2  012345678910  ASDA Butcher's Selection Lean Beef Mince (Typi...
# 3  012345678910               ASDA Grower's Selection Carrots 500g
# 4  012345678910                     ASDA Crispy Potato Slices 300g
#
#    substitution substituting  price  quantity  unit_price
# 0         False         None   1.59         1        1.59
# 1         False         None   6.50         2        3.25
# 2         False         None   2.97         1        2.97
# 3         False         None   0.33         1        0.33
# 4         False         None   0.85         1        0.85

# %% [markdown]
# ### Combine the substitution and ordered DataFrames to create delivered DataFrame
# I now want to combine the DataFrames df_subs and df_ordered.
#
# See both dataframes below:

# %%
df_subs.head()
# Out:
#    order_number                                              item  \
# 0  012345678910          ASDA Simply Cook Smoked Crispy Bacon 60g
# 1  012345678910        ASDA 2 Crisp Crumb Chunky Cod Fillets 350g
# 2  012345678910                 Yeo Valley Strawberry Yogurt 450g
# 3  012345678910       ASDA 18 Battered Chicken Breast Chunks 350g
# 4  012345678910  New York Bakery Co The Original Plain Bagels 5pk
#
#    substitution                                       substituting  price  \
# 0          True                 ASDA Diced Pancetta Twin Pack 160g   1.30
# 1          True  Young's 6 Chunky Fish Fillets in Crispy Breadc...   3.20
# 2          True                   Arla Skyr Strawberry Yogurt 450g   1.40
# 3          True             ASDA Crispy Chicken Breast Strips 400g   2.50
# 4          True                              ASDA Plain Bagels 4pk   0.69
#
#    quantity  unit_price
# 0         1        1.30
# 1         1        3.20
# 2         1        1.40
# 3         1        2.50
# 4         1        0.69

# %%
df_ordered.head()
# Out:
#    order_number                                               item  \
# 0  012345678910  ASDA Butcher's Selection Beef Mince (Typically...
# 1  012345678910  ASDA Butcher's Selection Prime Beef Ribeye Ste...
# 2  012345678910  ASDA Butcher's Selection Lean Beef Mince (Typi...
# 3  012345678910               ASDA Grower's Selection Carrots 500g
# 4  012345678910                     ASDA Crispy Potato Slices 300g
#
#    substitution substituting  price  quantity  unit_price
# 0         False         None   1.59         1        1.59
# 1         False         None   6.50         2        3.25
# 2         False         None   2.97         1        2.97
# 3         False         None   0.33         1        0.33
# 4         False         None   0.85         1        0.85

# %%
df_delivered = df_subs.append(df_ordered, ignore_index=True)

# %%
df_delivered
# Out:
#     order_number                                               item  \
# 0   012345678910           ASDA Simply Cook Smoked Crispy Bacon 60g
# 1   012345678910         ASDA 2 Crisp Crumb Chunky Cod Fillets 350g
# 2   012345678910                  Yeo Valley Strawberry Yogurt 450g
# 3   012345678910        ASDA 18 Battered Chicken Breast Chunks 350g
# 4   012345678910   New York Bakery Co The Original Plain Bagels 5pk
# 5   012345678910                 ASDA Creamy Tomato Pasta Bake 500g
# 6   012345678910   ASDA Butcher's Selection 8 Pork Loin Steaks 800g
# 7   012345678910                        ASDA GS Honeydew Melon EACH
# 8   012345678910             ASDA Mexican Style Plain Tortillas 8pk
# 9   012345678910  ASDA Butcher's Selection Beef Mince (Typically...
# 10  012345678910  ASDA Butcher's Selection Prime Beef Ribeye Ste...
# 11  012345678910  ASDA Butcher's Selection Lean Beef Mince (Typi...
# 12  012345678910               ASDA Grower's Selection Carrots 500g
# 13  012345678910                     ASDA Crispy Potato Slices 300g
# 14  012345678910  ASDA Butcher's Selection Chicken Breast Fillet...
# 15  012345678910  Cadbury Pots of Joy Dairy Milk Chocolate Desse...
# 16  012345678910   ASDA Thick Dry Cured Honey Roast Ham Slices 150g
# 17  012345678910      ASDA Simple to Cook Bourbon Beef Brisket 400g
# 18  012345678910                      Arla Skyr Vanilla Yogurt 450g
# 19  012345678910                 ASDA Grated Mozzarella Cheese 250g
# 20  012345678910           ASDA Butcher's Selection Diced Beef 475g
# 21  012345678910                 ASDA Grated Four Cheese Blend 200g
# 22  012345678910                ASDA Farm Stores White Potatoes 2kg
# 23  012345678910                    Aunt Bessie's 10 Dumplings 490g
# 24  012345678910        Richmond 20 Thick Frozen Pork Sausages 907g
# 25  012345678910  ASDA 4 Buttermilk Chicken Breast Fillet Burger...
# 26  012345678910  Maltesers Bunnies Large Chocolate Easter Egg 265g
# 27  012345678910  Cadbury Dairy Milk Caramel Gift Boxed Giant Ea...
# 28  012345678910  ASDA No Added Sugar Apple & Blackcurrant Squas...
# 29  012345678910                     Pepsi Max Raspberry Cans 8x330
# 30  012345678910                        Pepsi Max Cherry Cans 8x330
# 31  012345678910               ASDA Butter Chicken Curry Sauce 495g
# 32  012345678910          ASDA Grower's Selection Baby Potatoes 1kg
# 33  012345678910                               ASDA Mint Sauce 280g
# 34  012345678910          Weetabix Crispy Minis Chocolate Chip 600g
# 35  012345678910                    ASDA Bolognese Pasta Sauce 720g
# 36  012345678910                     Patak's Korma Curry Sauce 450g
# 37  012345678910                            ASDA Taco Seasoning 35g
# 38  012345678910                              ASDA Taco Shells 150g
# 39  012345678910                             ASDA Jam & Creams 150g
# 40  012345678910  ASDA Extra Special Hand Finished Salted Carame...
# 41  012345678910                           Kellogg's Coco Pops 480g
#
#     substitution                                       substituting  price  \
# 0           True                 ASDA Diced Pancetta Twin Pack 160g   1.30
# 1           True  Young's 6 Chunky Fish Fillets in Crispy Breadc...   3.20
# 2           True                   Arla Skyr Strawberry Yogurt 450g   1.40
# 3           True             ASDA Crispy Chicken Breast Strips 400g   2.50
# 4           True                              ASDA Plain Bagels 4pk   0.69
# 5           True              ASDA Tomato and Bacon Pasta Bake 480g   0.75
# 6           True  ASDA Butcher's Selection Pork Boneless & Rindl...   3.90
# 7           True      ASDA Grower's Selection Cantaloupe Melon each   1.69
# 8           True                  ASDA 10 Mini Plain Tortillas 300g   1.00
# 9          False                                               None   1.59
# 10         False                                               None   6.50
# 11         False                                               None   2.97
# 12         False                                               None   0.33
# 13         False                                               None   0.85
# 14         False                                               None   5.19
# 15         False                                               None   2.00
# 16         False                                               None   1.90
# 17         False                                               None   3.90
# 18         False                                               None   1.40
# 19         False                                               None   1.75
# 20         False                                               None   3.80
# 21         False                                               None   1.75
# 22         False                                               None   1.00
# 23         False                                               None   1.00
# 24         False                                               None   2.50
# 25         False                                               None   2.50
# 26         False                                               None   4.00
# 27         False                                               None   4.00
# 28         False                                               None   0.95
# 29         False                                               None   3.75
# 30         False                                               None   3.75
# 31         False                                               None   0.79
# 32         False                                               None   0.80
# 33         False                                               None   0.83
# 34         False                                               None   2.98
# 35         False                                               None   0.84
# 36         False                                               None   1.00
# 37         False                                               None   1.24
# 38         False                                               None   1.30
# 39         False                                               None   0.45
# 40         False                                               None   1.85
# 41         False                                               None   2.89
#
#     quantity  unit_price
# 0          1        1.30
# 1          1        3.20
# 2          1        1.40
# 3          1        2.50
# 4          1        0.69
# 5          1        0.75
# 6          1        3.90
# 7          1        1.69
# 8          1        1.00
# 9          1        1.59
# 10         2        3.25
# 11         1        2.97
# 12         1        0.33
# 13         1        0.85
# 14         1        5.19
# 15         2        1.00
# 16         1        1.90
# 17         1        3.90
# 18         1        1.40
# 19         1        1.75
# 20         1        3.80
# 21         1        1.75
# 22         1        1.00
# 23         1        1.00
# 24         1        2.50
# 25         1        2.50
# 26         1        4.00
# 27         1        4.00
# 28         1        0.95
# 29         1        3.75
# 30         1        3.75
# 31         1        0.79
# 32         1        0.80
# 33         1        0.83
# 34         1        2.98
# 35         1        0.84
# 36         1        1.00
# 37         2        0.62
# 38         1        1.30
# 39         1        0.45
# 40         1        1.85
# 41         1        2.89

# %% [markdown]
# ### Clean the unavailable DataFrame
#
# Currently looks like this:

# %%
df_unavail.head()
# Out:
#                                     item quantity  price
# 0             ASDA Peppercorn Sauce 200g        1  £0.00
# 1                      ASDA Fusilli 500g        3  £0.00
# 2                   ASDA Conchiglie 500g        1  £0.00
# 3      ASDA 6 Medium Free Range Eggs 6pk        1  £0.00
# 4  George Home Plastic Food Storers 3x1l        1  £0.00

# %% [markdown]
# We want to:
# 1. Add the order number
# 2. Convert quantity to an integer
# 3. Drop price Column

# %%
df_unavail.insert(0, 'order_number', order_number)
df_unavail.head()
# Out:
#    order_number                                   item quantity  price
# 0  012345678910             ASDA Peppercorn Sauce 200g        1  £0.00
# 1  012345678910                      ASDA Fusilli 500g        3  £0.00
# 2  012345678910                   ASDA Conchiglie 500g        1  £0.00
# 3  012345678910      ASDA 6 Medium Free Range Eggs 6pk        1  £0.00
# 4  012345678910  George Home Plastic Food Storers 3x1l        1  £0.00

# %%
# Convert quantity to a integer
df_unavail['quantity'] = df_unavail['quantity'].astype('int', errors='ignore')
df_unavail.head()
# Out:
#    order_number                                   item  quantity  price
# 0  012345678910             ASDA Peppercorn Sauce 200g         1  £0.00
# 1  012345678910                      ASDA Fusilli 500g         3  £0.00
# 2  012345678910                   ASDA Conchiglie 500g         1  £0.00
# 3  012345678910      ASDA 6 Medium Free Range Eggs 6pk         1  £0.00
# 4  012345678910  George Home Plastic Food Storers 3x1l         1  £0.00

# %%
df_unavail.dtypes
# Out:
# order_number    object
# item            object
# quantity         int32
# price           object
# dtype: object

# %%
df_unavail = df_unavail.drop(['price'], axis=1)
df_unavail.head()
# Out:
#    order_number                                   item  quantity
# 0  012345678910             ASDA Peppercorn Sauce 200g         1
# 1  012345678910                      ASDA Fusilli 500g         3
# 2  012345678910                   ASDA Conchiglie 500g         1
# 3  012345678910      ASDA 6 Medium Free Range Eggs 6pk         1
# 4  012345678910  George Home Plastic Food Storers 3x1l         1

# %% [markdown]
# ### Add to the order details DataFrame
#
# Currently the DataFrame looks like this:

# %%
df_order_details.head()
# Out:
#    order_number delivery_date  subtotal  total
# 0  012345678910    2020-03-26     89.68  83.01

# %% [markdown]
# We want it to look like this:
#
# order_number|delivery_date|subtotal|total|
# ------------|-------------|--------|-----|

# %% [markdown]
# The only changes we need to make are to convert the delivery date to a datetime format.

# %%
# Convert date tp datetime
df_order_details['delivery_date'] = pd.to_datetime(df_order_details['delivery_date'])

# %%
df_order_details.dtypes
# Out:
# order_number             object
# delivery_date    datetime64[ns]
# subtotal                float64
# total                   float64
# dtype: object

# %%
df_order_details.head()
# Out:
#    order_number delivery_date  subtotal  total
# 0  012345678910    2020-03-26     89.68  83.01

# %% [markdown]
# ## Summary of the DataFrames we have
#
# We now have three DataFrames:
#
# 1. The delivered Dataframe which contains the items that were actually delivered and whether they are substitutions or as ordered
# 2. Unavialable items which were not substituted and therefore not delivered
# 3. An order details DataFrame which summaries some of the key information about the order

# %%
df_delivered.head()
# Out:
#    order_number                                              item  \
# 0  012345678910          ASDA Simply Cook Smoked Crispy Bacon 60g
# 1  012345678910        ASDA 2 Crisp Crumb Chunky Cod Fillets 350g
# 2  012345678910                 Yeo Valley Strawberry Yogurt 450g
# 3  012345678910       ASDA 18 Battered Chicken Breast Chunks 350g
# 4  012345678910  New York Bakery Co The Original Plain Bagels 5pk
#
#    substitution                                       substituting  price  \
# 0          True                 ASDA Diced Pancetta Twin Pack 160g   1.30
# 1          True  Young's 6 Chunky Fish Fillets in Crispy Breadc...   3.20
# 2          True                   Arla Skyr Strawberry Yogurt 450g   1.40
# 3          True             ASDA Crispy Chicken Breast Strips 400g   2.50
# 4          True                              ASDA Plain Bagels 4pk   0.69
#
#    quantity  unit_price
# 0         1        1.30
# 1         1        3.20
# 2         1        1.40
# 3         1        2.50
# 4         1        0.69

# %%
df_unavail.head()
# Out:
#    order_number                                   item  quantity
# 0  012345678910             ASDA Peppercorn Sauce 200g         1
# 1  012345678910                      ASDA Fusilli 500g         3
# 2  012345678910                   ASDA Conchiglie 500g         1
# 3  012345678910      ASDA 6 Medium Free Range Eggs 6pk         1
# 4  012345678910  George Home Plastic Food Storers 3x1l         1

# %%
df_order_details.head()
# Out:
#    order_number delivery_date  subtotal  total
# 0  012345678910    2020-03-26     89.68  83.01

# %% [markdown]
# ## Save to CSV

# %%
filename_delivered = 'Delivered_Items_'+ str(delivery_date) + '.csv'

df_delivered.to_csv(filename_delivered, index=False)

# %% [markdown]
# # Inserting into Tables on a PostgreSQL database
# I have create the following tables in a PostgreSQL Database:
# * order_details
# * delivered_items
# * unavailable_items
#
# The SQL to create these tables:
#
# 1) order_details
# ```SQL
# CREATE TABLE order_details
# (
# 	order_number VARCHAR PRIMARY KEY,
# 	delivery_date DATE NOT NULL,
# 	subtotal NUMERIC(5, 2),
# 	total NUMERIC(5, 2)
# );
# ```
# 2) delivered_items
# ```PostgreSQL
# CREATE TABLE delivered_items
# (
# 	id serial PRIMARY KEY,
# 	order_number VARCHAR REFERENCES order_details(order_number),
# 	item VARCHAR NOT NULL,
# 	substitution BOOL NOT NULL,
# 	substituting VARCHAR,
# 	price NUMERIC(5, 2),
# 	quantity SMALLINT,
# 	unit_price NUMERIC(5, 2)
# );
# ```
# 3) unavailable_items
# ```PostgreSQL
# CREATE TABLE unavailable_items
# (
#     id serial PRIMARY Key,
#     order_number VARCHAR REFERENCES order_details(order_number),
#     item VARCHAR NOT NULL,
#     quantity SMALLINT
# );
# ```

# %% [markdown]
# For the purposes of this notebook I have created test versions of the above. The idea being that the Extract_Script.py script will add to the database and the test versions are for experimenting in the notebooks.

# %%
# Testing connection to database

from config import config

def connect():
    """ Connect to the PostgreSQL database server """
    conn = None
    try:
        # read connection parameters
        params = config()

        # connect to the PostgreSQL server
        print('Connecting to the PostgreSQL database...')
        conn = psycopg2.connect(**params)
		
        # create a cursor
        cur = conn.cursor()
        
	# execute a statement
        print('PostgreSQL database version:')
        cur.execute('SELECT version()')

        # display the PostgreSQL database server version
        db_version = cur.fetchone()
        print(db_version)
       
	    # close the communication with the PostgreSQL
        cur.close()
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
    finally:
        if conn is not None:
            conn.close()
            print('Database connection closed.')


if __name__ == '__main__':
    connect()
# Out:
# Connecting to the PostgreSQL database...
# PostgreSQL database version:
# ('PostgreSQL 12.2, compiled by Visual C++ build 1914, 64-bit',)
# Database connection closed.

# %%
import credentials
username = credentials.username
password = credentials.password
database = credentials.database
engine = create_engine('postgresql+psycopg2://{}:{}@localhost/{}'.format(username, password, database))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-d5ea6fe75eef> in <module>
#       3 password = credentials.password
#       4 database = credentials.database
# ----> 5 engine = create_engine('postgresql+psycopg2://{}:{}@localhost/{}'.format(username, password, database))
#
# NameError: name 'create_engine' is not defined

# %%
df_order_details.to_sql('order_details_test', con = engine, if_exists='append', index=False)

# %%
df_delivered.dtypes

# %%
df_delivered.to_sql('delivered_items_test', con = engine, if_exists='append', index=False)

# %%
df_unavail.to_sql('unavailable_items_test', con = engine, if_exists='append', index=False)

# %% [markdown]
# To test they have inserted correctly:

# %%
# %load_ext sql

# %%
sqlalchemy.create_engine('postgresql+psycopg2://{}:{}@localhost/{}'.format(username, password, database))

# %%
# %sql postgresql+psycopg2://postgres:password@localhost/groceries

# %%
# %%sql
#
# SELECT * FROM order_details_test

# %%
# %%sql
#
# SELECT * FROM delivered_items_test

# %%
# %%sql
#
# SELECT * FROM unavailable_items_test

# %% [markdown]
# # Updated email template
#
# The formatting of the email changed for my order on 08/07/20. I will therefore Try and change my extraction method below. For my extract_script.py I will add in a condition that checks the subject line, as the subject has been changed from _'Your Updated ASDA Groceries Order'_ to _'Order Receipt'_

# %%
with open('Order Receipt.eml', 'r') as file:
   
   msg2 = email.message_from_file(file, policy=default)

# %%
# Extract the parts of the message and enter it into a dictionary
body = msg2.get_payload(decode=True)
dict = {'to': msg2['to'], 'from': msg2['from'], 'subject': msg2['subject'], 'date': msg2['date'], 'body': body}
print('To: {}'.format(msg2['to']))
print('From: {}'.format(msg2['from']))
print('Date: {}'.format(msg2['date']))
print('Subject: {}'.format(msg2['subject']))
# Out:
# To: "example@email.com" <example@email.com>
# From: ASDA Customer Services <home.shopping@asda.co.uk>
# Date: Wed, 08 Jul 2020 12:31:00 +0100
# Subject: Order Receipt

# %%
#Grab the HTML from the body of the email and extract the table element
html = HTML(html=body)

match = html.find('tr')
print(match)
# Out:
# [<Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' style='padding-left: 24px'>, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' style='border-radius: 2px;background-color: #eeeeee;margin-top: 20px'>, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' style='border-radius: 2px;background-color: #eeeeee;margin-top: 20px'>, <Element 'tr' >, <Element 'tr' style='border-radius: 2px;background-color: #eeeeee;margin-top: 20px'>, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' style='border-radius: 2px;background-color: #eeeeee;margin-top: 20px'>, <Element 'tr' >, <Element 'tr' style='border-radius: 2px;background-color: #eeeeee;margin-top: 20px'>, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' >, <Element 'tr' style='padding-left: 24px'>]

# %%
#All the tr elements in match are the same
i=0
equiv = []
while i < len(match):
    equiv.append(str(match[0]) == str(match[i]))
    i += 1
print(equiv)
# Out:
# [True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False, True, False, True, True, True, True, True, True, False, True, False, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, True, False]

# %%
content = match[0].text
lines = content.splitlines()
for i, line in enumerate(lines):
    print(i, line)
# Out:
# 0 Order Receipt:
# 1 22005499653
# 2
# 3
# 4 Address goes Here
# 5 Wednesday, 8 July, 06:00 PM-08:00 PM
# 6 £110.17
# 7
# 8
# 9 Track package
# 10 Bring your bags to help us reduce plastic.
# 11 Paid with a gift card? Keep it safe until you get your order.
# 12
# 13
# 14 Everything ok with your order? Hand back anything you do not want or leave it in the locker. We’ll refund you straight away.
# 15 Or ask for a refund online up to 3 days after you get your order.
# 16 Changes to your order
# 17 We only charge you for the items we send. We never charge you more for a substitute, even when the substitute is more expensive.
# 18
# 19
# 20 You ordered
# 21 1 X Goodfella's Stonebaked Thin Pepperoni Pizza 340g
# 22 £1.50
# 23 We sent
# 24 1 X Goodfella's Stonebaked Thin Roast Chicken Pizza 365g
# 25 £1.50
# 26 You ordered
# 27 1 X Blue Dragon Light Soy Sauce 375ml
# 28 £1.88
# 29 We sent
# 30 3 X ASDA Light Soy Sauce 150ml
# 31 £1.62
# 32 You ordered
# 33 1 X ASDA Plant Based Meat-Free Sausages 270g
# 34 Not available
# 35 £2.35
# 36 You ordered
# 37 1 X ASDA Cookies & Cream Celebration Cake each
# 38 Not available
# 39 £13.00
# 40 Your order
# 41
# 42
# 43 Fridge
# 44 Quantity
# 45 Price
# 46 ASDA Butcher's Selection 6 Thick Cut Smoked Back Bacon Rashers 300g
# 47 2
# 48 £3.38
# 49 ASDA Light Mozzarella Cheese 125g
# 50 1
# 51 £0.49
# 52 ASDA Halloumi 225g
# 53 1
# 54 £1.75
# 55 ASDA Sour Cream & Chive Dip 200g
# 56 1
# 57 £0.90
# 58 ASDA Butcher's Selection 8 Minted Lamb Kofta Kebabs 480g
# 59 1
# 60 £4.00
# 61 ASDA Butcher's Selection 4 BBQ Pork Kebabs 344g
# 62 1
# 63 £3.00
# 64 Cadbury Layers of Joy Chocolate Trifles 2x90g
# 65 1
# 66 £1.00
# 67 ASDA Grower's Selection Little Gem Lettuce 2pk
# 68 1
# 69 £0.65
# 70 ASDA Houmous 200g
# 71 1
# 72 £0.80
# 73 ASDA Grower's Selection Spring Onions each
# 74 1
# 75 £0.55
# 76 Apetina Classic Light Salad Cheese 200g
# 77 1
# 78 £1.00
# 79 ASDA Butcher's Selection Chicken Breast Fillets 650g
# 80 1
# 81 £3.40
# 82 ASDA Grated Mature Cheddar 250g
# 83 1
# 84 £1.75
# 85 ASDA Extra Special Baby Potatoes 1kg
# 86 1
# 87 £1.00
# 88 ASDA Extra Special 6 Pork & Caramelised Red Onion Sausages 400g
# 89 1
# 90 £2.25
# 91 ASDA Grower's Selection Cucumber each
# 92 1
# 93 £0.55
# 94 ASDA Extra Special 6 Lincolnshire Pork Sausages 400g
# 95 1
# 96 £2.25
# 97 Arla Skyr Natural Yogurt 450g
# 98 1
# 99 £1.25
# 100 ASDA Butcher's Selection Chinese Pork Loin Steaks 880g
# 101 1
# 102 £5.00
# 103 Lurpak Lighter Slightly Salted Spreadable 750g
# 104 1
# 105 £4.00
# 106 ASDA Grower's Selection Sweetcorn Cobettes 4pk
# 107 2
# 108 £2.00
# 109 ASDA Butcher's Selection Lean Beef Mince (Typically Less Than 5% Fat) 500g
# 110 2
# 111 £5.94
# 112 Others
# 113 Quantity
# 114 Price
# 115 ASDA Grower's Selection Loose Red Onion (order by number of onions or select kg) per kg
# 116 0.11kg
# 117 £0.09
# 118 Freezer
# 119 Quantity
# 120 Price
# 121 Toblerone Cheesecake 430g
# 122 1
# 123 £3.00
# 124 McCain Frozen Home Chips Straight 2.1kg
# 125 1
# 126 £3.00
# 127 Birds Eye 8 Crispy Battered Fish Fingers 224g
# 128 1
# 129 £1.58
# 130 ASDA Take Away BBQ Chicken & Bacon Stuffed Crust Pizza 458g
# 131 1
# 132 £2.00
# 133 ASDA 18 Battered Chicken Breast Chunks 350g
# 134 1
# 135 £2.50
# 136 Birds Eye 2 Original Chicken Chargrills 170g
# 137 1
# 138 £1.65
# 139 Fresh
# 140 Quantity
# 141 Price
# 142 ASDA White Pitta Breads 6pk
# 143 2
# 144 £0.90
# 145 Groceries, Health & Beauty and Household Items
# 146 Quantity
# 147 Price
# 148 Expert Grill 30cm Bamboo Skewers 100pk
# 149 1
# 150 £1.00
# 151 Birra Moretti Premium Lager 12x330
# 152 1
# 153 £12.00
# 154 ASDA 100% Pure Apple Juice Carton 1l
# 155 1
# 156 £0.65
# 157 Schweppes Slimline Lemonade 2lt
# 158 1
# 159 £1.00
# 160 ASDA Grower's Selection Mint 25g
# 161 1
# 162 £0.40
# 163 ASDA Grower's Selection Baby Plum Tomatoes 325g
# 164 1
# 165 £0.95
# 166 ASDA Grower's Selection Loose Lemon each
# 167 1
# 168 £0.30
# 169 Nishaan Plain Parathas 380g
# 170 1
# 171 £1.10
# 172 Napolina Italian Grated Cheese 80g
# 173 1
# 174 £1.89
# 175 ASDA 12 Large Free Range Eggs 12pk
# 176 1
# 177 £2.05
# 178 Douwe Egberts Pure Gold Medium Roast Instant Coffee 190g
# 179 1
# 180 £5.00
# 181 Batchelors Original Mushy Peas 3x300g
# 182 1
# 183 £1.40
# 184 Schweppes Lemonade 2lt
# 185 1
# 186 £1.00
# 187 ASDA Farm Stores Salad Tomatoes 6pk
# 188 1
# 189 £0.75
# 190 ASDA Pineapple Juice 1l
# 191 1
# 192 £0.80
# 193 Pepsi Max 2lt
# 194 2
# 195 £3.96
# 196 ASDA Lemon Juice from Concentrate 250ml
# 197 1
# 198 £0.39
# 199 ASDA White Basmati Rice 2kg
# 200 1
# 201 £2.89
# 202 ASDA Grower's Selection Sweet Peppers (Colour may vary) 3pk
# 203 1
# 204 £1.35
# 205 Belvita Breakfast Biscuits Soft Bakes Filled Choco Hazelnut 5 Pack 250g
# 206 1
# 207 £1.50
# 208 Belvita Breakfast Biscuits Cocoa with Choc Chips 5 Pack 225g
# 209 1
# 210 £1.00
# 211 ASDA No Added Sugar Double Strength Summer Fruits Squash 1.5l
# 212 1
# 213 £1.00
# 214 Popchips Sour Cream and Onion Sharing Crisps 85g
# 215 1
# 216 £1.00
# 217 ASDA Meatballs Pasta Sauce 500g
# 218 1
# 219 £0.79
# 220 Maggi So Tender Italian Herbs Chicken 23g
# 221 1
# 222 £0.75
# 223 Popchips Barbeque Sharing Crisps 85g
# 224 1
# 225 £1.00
# 226
# 227
# 228 Groceries
# 229 £110.67
# 230 Pick & pack*
# 231 £0.00
# 232 Minimum basket charge
# 233 £0.00
# 234
# 235 Savings
# 236 Multibuy (1 items)
# 237 -£0.50
# 238
# 239 Order total
# 240 £110.17
# 241
# 242 When we charge you
# 243 We set up your payment the day before your order. That way we can warn you if there are payment problems. We only charge you on the day.
# 244 Sometimes your order total changes after we set up the payment. For example because of last minute changes to your order, or the exact weight of your fresh food.
# 245 If so we’ll make corrections on the day. You’ll see these on your bank statement as extra charges/refunds. Some banks may take a few days to then update your account.
# 246 Payment details
# 247 ••••
# 248 £125.69
# 249 *Exact price depends on weight of available items
# 250 View order online
# 251 endif]--></td></tr></tbody></table></td></tr><img src="https://rptrcks.walmart.com/comm-smart-app/services/tracking/openTracker?redirectTo=lBomOh6WKvUucY3E3HMu4XvON0cnNY20QfPCNVStDrglTIclmI0iCV1wUTF%2Bc8fi7cDr%2BNSp9M8byEwiZYONH4zKQVHUOkewAW6ryJn/nz7JcB%2BsP0qpSxkyIiZvMURdhOaL4tHoIAshuMF74Z0JEAs/fsOvzSUBdFeI196u0O%2Bu/bH1JroLeSwfxaNQJjQcfgEXrP7Qx7FwvBOzy8O4uQhp1dcjea1UOiC87YlH8mo%2Bw71o3Z2BntuhvfGLgNqny/I8EcNbZGDqYvQ69cqmkL/qtqQBBdJRrd/NZj01/yf/At%2BFHFItZuFuK1xC%&meta=ezq6KFZhFKSXvcqRwURdrWgGRey8UWreqgFA3zXp2Y56zOFRfxZnCElMkFVcTm1dBscuwiXpas5P4od5FJg8IZEUJWo3yBB6dbU%2F%2FKQDtobN2%2Fg5yRALrNdemBrG1ucMmWGsB6oWC2uflVqLOLB7BhCffuvPAI5%2BVwkIA22I2iKHVlkq3WyoRLsS%2Fvx7BXD6vMKHXR3LvxWpwHUXoulhgQDvYhzmUL0b%2FZa3oykOiJk%3D&iv=jtGu2NvGIFaAne9sWxajIg%3D%3D" height="1" width="1"> <img height="1" alt="" src="http://omniture.groceries.asda.com/b/ss/wmiasdaemailprod/5?pageName=WismoEmailOpenRate&v1=eDeliveryNoteemaildeliveryorders" width="1" border="0"><!-- body --><!-- Footer Starts --><!-- Footer Starts --> <tr><!--[if mso
# 252 endif]--><!--[if !mso-->
# 253 Please do not reply to this email.
# 254 If you’d like to get in touch, please call our customer services team on 0800 952 6060.
# 255
# 256 This is a service message from Asda Stores Ltd, Registered in England No. 464777.
# 257 Registered Office: Asda House, Southbank, Great Wilson Street, Leeds LS11 5AD
# 258
# 259 This email and any files transmitted with it are confidential and intended solely for the individual or entity to whom they are addressed. If you have received this email in error please accept our apologies & destroy it immediately.
# 260 ASDA 2018
# 261 Terms & Conditions ⋅ Privacy & Cookies Policy

# %%
try:
    remove_index = lines.index('You still get your discount')
    lines.pop(remove_index)
except:
    pass

# %%
for i, line in enumerate(lines):
    print(i, line)
# Out:
# 0 Order Receipt:
# 1 22005499653
# 2
# 3
# 4 Address goes Here
# 5 Wednesday, 8 July, 06:00 PM-08:00 PM
# 6 £110.17
# 7
# 8
# 9 Track package
# 10 Bring your bags to help us reduce plastic.
# 11 Paid with a gift card? Keep it safe until you get your order.
# 12
# 13
# 14 Everything ok with your order? Hand back anything you do not want or leave it in the locker. We’ll refund you straight away.
# 15 Or ask for a refund online up to 3 days after you get your order.
# 16 Changes to your order
# 17 We only charge you for the items we send. We never charge you more for a substitute, even when the substitute is more expensive.
# 18
# 19
# 20 You ordered
# 21 1 X Goodfella's Stonebaked Thin Pepperoni Pizza 340g
# 22 £1.50
# 23 We sent
# 24 1 X Goodfella's Stonebaked Thin Roast Chicken Pizza 365g
# 25 £1.50
# 26 You ordered
# 27 1 X Blue Dragon Light Soy Sauce 375ml
# 28 £1.88
# 29 We sent
# 30 3 X ASDA Light Soy Sauce 150ml
# 31 £1.62
# 32 You ordered
# 33 1 X ASDA Plant Based Meat-Free Sausages 270g
# 34 Not available
# 35 £2.35
# 36 You ordered
# 37 1 X ASDA Cookies & Cream Celebration Cake each
# 38 Not available
# 39 £13.00
# 40 Your order
# 41
# 42
# 43 Fridge
# 44 Quantity
# 45 Price
# 46 ASDA Butcher's Selection 6 Thick Cut Smoked Back Bacon Rashers 300g
# 47 2
# 48 £3.38
# 49 ASDA Light Mozzarella Cheese 125g
# 50 1
# 51 £0.49
# 52 ASDA Halloumi 225g
# 53 1
# 54 £1.75
# 55 ASDA Sour Cream & Chive Dip 200g
# 56 1
# 57 £0.90
# 58 ASDA Butcher's Selection 8 Minted Lamb Kofta Kebabs 480g
# 59 1
# 60 £4.00
# 61 ASDA Butcher's Selection 4 BBQ Pork Kebabs 344g
# 62 1
# 63 £3.00
# 64 Cadbury Layers of Joy Chocolate Trifles 2x90g
# 65 1
# 66 £1.00
# 67 ASDA Grower's Selection Little Gem Lettuce 2pk
# 68 1
# 69 £0.65
# 70 ASDA Houmous 200g
# 71 1
# 72 £0.80
# 73 ASDA Grower's Selection Spring Onions each
# 74 1
# 75 £0.55
# 76 Apetina Classic Light Salad Cheese 200g
# 77 1
# 78 £1.00
# 79 ASDA Butcher's Selection Chicken Breast Fillets 650g
# 80 1
# 81 £3.40
# 82 ASDA Grated Mature Cheddar 250g
# 83 1
# 84 £1.75
# 85 ASDA Extra Special Baby Potatoes 1kg
# 86 1
# 87 £1.00
# 88 ASDA Extra Special 6 Pork & Caramelised Red Onion Sausages 400g
# 89 1
# 90 £2.25
# 91 ASDA Grower's Selection Cucumber each
# 92 1
# 93 £0.55
# 94 ASDA Extra Special 6 Lincolnshire Pork Sausages 400g
# 95 1
# 96 £2.25
# 97 Arla Skyr Natural Yogurt 450g
# 98 1
# 99 £1.25
# 100 ASDA Butcher's Selection Chinese Pork Loin Steaks 880g
# 101 1
# 102 £5.00
# 103 Lurpak Lighter Slightly Salted Spreadable 750g
# 104 1
# 105 £4.00
# 106 ASDA Grower's Selection Sweetcorn Cobettes 4pk
# 107 2
# 108 £2.00
# 109 ASDA Butcher's Selection Lean Beef Mince (Typically Less Than 5% Fat) 500g
# 110 2
# 111 £5.94
# 112 Others
# 113 Quantity
# 114 Price
# 115 ASDA Grower's Selection Loose Red Onion (order by number of onions or select kg) per kg
# 116 0.11kg
# 117 £0.09
# 118 Freezer
# 119 Quantity
# 120 Price
# 121 Toblerone Cheesecake 430g
# 122 1
# 123 £3.00
# 124 McCain Frozen Home Chips Straight 2.1kg
# 125 1
# 126 £3.00
# 127 Birds Eye 8 Crispy Battered Fish Fingers 224g
# 128 1
# 129 £1.58
# 130 ASDA Take Away BBQ Chicken & Bacon Stuffed Crust Pizza 458g
# 131 1
# 132 £2.00
# 133 ASDA 18 Battered Chicken Breast Chunks 350g
# 134 1
# 135 £2.50
# 136 Birds Eye 2 Original Chicken Chargrills 170g
# 137 1
# 138 £1.65
# 139 Fresh
# 140 Quantity
# 141 Price
# 142 ASDA White Pitta Breads 6pk
# 143 2
# 144 £0.90
# 145 Groceries, Health & Beauty and Household Items
# 146 Quantity
# 147 Price
# 148 Expert Grill 30cm Bamboo Skewers 100pk
# 149 1
# 150 £1.00
# 151 Birra Moretti Premium Lager 12x330
# 152 1
# 153 £12.00
# 154 ASDA 100% Pure Apple Juice Carton 1l
# 155 1
# 156 £0.65
# 157 Schweppes Slimline Lemonade 2lt
# 158 1
# 159 £1.00
# 160 ASDA Grower's Selection Mint 25g
# 161 1
# 162 £0.40
# 163 ASDA Grower's Selection Baby Plum Tomatoes 325g
# 164 1
# 165 £0.95
# 166 ASDA Grower's Selection Loose Lemon each
# 167 1
# 168 £0.30
# 169 Nishaan Plain Parathas 380g
# 170 1
# 171 £1.10
# 172 Napolina Italian Grated Cheese 80g
# 173 1
# 174 £1.89
# 175 ASDA 12 Large Free Range Eggs 12pk
# 176 1
# 177 £2.05
# 178 Douwe Egberts Pure Gold Medium Roast Instant Coffee 190g
# 179 1
# 180 £5.00
# 181 Batchelors Original Mushy Peas 3x300g
# 182 1
# 183 £1.40
# 184 Schweppes Lemonade 2lt
# 185 1
# 186 £1.00
# 187 ASDA Farm Stores Salad Tomatoes 6pk
# 188 1
# 189 £0.75
# 190 ASDA Pineapple Juice 1l
# 191 1
# 192 £0.80
# 193 Pepsi Max 2lt
# 194 2
# 195 £3.96
# 196 ASDA Lemon Juice from Concentrate 250ml
# 197 1
# 198 £0.39
# 199 ASDA White Basmati Rice 2kg
# 200 1
# 201 £2.89
# 202 ASDA Grower's Selection Sweet Peppers (Colour may vary) 3pk
# 203 1
# 204 £1.35
# 205 Belvita Breakfast Biscuits Soft Bakes Filled Choco Hazelnut 5 Pack 250g
# 206 1
# 207 £1.50
# 208 Belvita Breakfast Biscuits Cocoa with Choc Chips 5 Pack 225g
# 209 1
# 210 £1.00
# 211 ASDA No Added Sugar Double Strength Summer Fruits Squash 1.5l
# 212 1
# 213 £1.00
# 214 Popchips Sour Cream and Onion Sharing Crisps 85g
# 215 1
# 216 £1.00
# 217 ASDA Meatballs Pasta Sauce 500g
# 218 1
# 219 £0.79
# 220 Maggi So Tender Italian Herbs Chicken 23g
# 221 1
# 222 £0.75
# 223 Popchips Barbeque Sharing Crisps 85g
# 224 1
# 225 £1.00
# 226
# 227
# 228 Groceries
# 229 £110.67
# 230 Pick & pack*
# 231 £0.00
# 232 Minimum basket charge
# 233 £0.00
# 234
# 235 Savings
# 236 Multibuy (1 items)
# 237 -£0.50
# 238
# 239 Order total
# 240 £110.17
# 241
# 242 When we charge you
# 243 We set up your payment the day before your order. That way we can warn you if there are payment problems. We only charge you on the day.
# 244 Sometimes your order total changes after we set up the payment. For example because of last minute changes to your order, or the exact weight of your fresh food.
# 245 If so we’ll make corrections on the day. You’ll see these on your bank statement as extra charges/refunds. Some banks may take a few days to then update your account.
# 246 Payment details
# 247 ••••
# 248 £125.69
# 249 *Exact price depends on weight of available items
# 250 View order online
# 251 endif]--></td></tr></tbody></table></td></tr><img src="https://rptrcks.walmart.com/comm-smart-app/services/tracking/openTracker?redirectTo=lBomOh6WKvUucY3E3HMu4XvON0cnNY20QfPCNVStDrglTIclmI0iCV1wUTF%2Bc8fi7cDr%2BNSp9M8byEwiZYONH4zKQVHUOkewAW6ryJn/nz7JcB%2BsP0qpSxkyIiZvMURdhOaL4tHoIAshuMF74Z0JEAs/fsOvzSUBdFeI196u0O%2Bu/bH1JroLeSwfxaNQJjQcfgEXrP7Qx7FwvBOzy8O4uQhp1dcjea1UOiC87YlH8mo%2Bw71o3Z2BntuhvfGLgNqny/I8EcNbZGDqYvQ69cqmkL/qtqQBBdJRrd/NZj01/yf/At%2BFHFItZuFuK1xC%&meta=ezq6KFZhFKSXvcqRwURdrWgGRey8UWreqgFA3zXp2Y56zOFRfxZnCElMkFVcTm1dBscuwiXpas5P4od5FJg8IZEUJWo3yBB6dbU%2F%2FKQDtobN2%2Fg5yRALrNdemBrG1ucMmWGsB6oWC2uflVqLOLB7BhCffuvPAI5%2BVwkIA22I2iKHVlkq3WyoRLsS%2Fvx7BXD6vMKHXR3LvxWpwHUXoulhgQDvYhzmUL0b%2FZa3oykOiJk%3D&iv=jtGu2NvGIFaAne9sWxajIg%3D%3D" height="1" width="1"> <img height="1" alt="" src="http://omniture.groceries.asda.com/b/ss/wmiasdaemailprod/5?pageName=WismoEmailOpenRate&v1=eDeliveryNoteemaildeliveryorders" width="1" border="0"><!-- body --><!-- Footer Starts --><!-- Footer Starts --> <tr><!--[if mso
# 252 endif]--><!--[if !mso-->
# 253 Please do not reply to this email.
# 254 If you’d like to get in touch, please call our customer services team on 0800 952 6060.
# 255
# 256 This is a service message from Asda Stores Ltd, Registered in England No. 464777.
# 257 Registered Office: Asda House, Southbank, Great Wilson Street, Leeds LS11 5AD
# 258
# 259 This email and any files transmitted with it are confidential and intended solely for the individual or entity to whom they are addressed. If you have received this email in error please accept our apologies & destroy it immediately.
# 260 ASDA 2018
# 261 Terms & Conditions ⋅ Privacy & Cookies Policy

# %%
try:
    order_number = lines[lines.index('Order Receipt:') + 1]
except:
    order_number = lines[lines.index('Order Number:') + 1]
delivery_date_str = lines[5]
total_str = lines[lines.index('Order total') + 1]
subtotal_str = lines[lines.index('Groceries') + 1]

# %%
print(f'order number: {order_number}')
print(f'delivery date string: {delivery_date_str}')
print(f'total cost: {total_str}')
print(f'subtotal: {subtotal_str}')
# Out:
# order number: 22110077891
# delivery date string: Wednesday, 29 July, 05:00 PM-07:00 PM
# total cost: £79.14
# subtotal: £82.22

# %% [markdown]
# ### Converting Date
# The year is not in the delivery date string. Therefore I will use the date the email was sent as the delivery date. this is valid as the email is sent on the same day as the delivery

# %%
print(msg2['Date'])
delivery_date_str = msg2['date'][0:16]
print(delivery_date_str)
# Out:
# Wed, 29 Jul 2020 12:02:32 +0100
# Wed, 29 Jul 2020

# %%
#converting date 
delivery_date = datetime.datetime.strptime(delivery_date_str, '%a, %d %b %Y').date()
delivery_date
# Out:
# datetime.date(2020, 7, 29)

# %% [markdown]
# ### converting total and subtotal to floats

# %%
subtotal = convert_str_price_to_float(subtotal_str)
print('Subtotal     :', subtotal, type(subtotal))

total = convert_str_price_to_float(total_str)
print('Total        :', total, type(total))
# Out:
# Subtotal     : 82.22 <class 'float'>
# Total        : 79.14 <class 'float'>

# %% [markdown]
# ### Creating substitution and Unavailable Lists

# %%
# getting substitutions and unavailable items start and end lines
#substitutions and unavailable start with the first 'you ordered' header
#substitutions end with your order

subs_start = lines.index('You ordered')
subs_end = lines.index('Your order')

# %%
#next I will get the position of the lines 'you ordered' and the lines 'we sent'

you_ordered_lines = []
we_sent_lines = []
not_available_lines = []
i = subs_start

while i < subs_end:
    if lines[i] == 'You ordered':
        you_ordered_lines.append(i)
        i += 1
    elif lines[i] == 'We sent':
        we_sent_lines.append(i)
        i += 1
    elif lines[i] == 'Not available':
        not_available_lines.append(i)
        i += 1
    else:
        i += 1

# %%
you_ordered_lines
# Out:
# [20, 26, 32, 38]

# %%
we_sent_lines
# Out:
# [23, 29, 35, 41]

# %%
not_available_lines
# Out:
# []

# %% [markdown]
# As can be seen above the first two items under 'You ordered' we substituted, the second two we unavailable. I would like to create a list of tuples similar to the original template.

# %%
# lines[i - 2] gives the original item, lines[i + 1], gives the substitution
#retrieveing the first character, lines[i + 1][0], gives the quantity
#line[i + 2] gives the price
substitutes = []
for i in we_sent_lines:
    substitutes.append((lines[i + 1][4:], lines[i - 2][4:], lines[i + 1][0], lines[i + 2]))

# %%
substitutes
# Out:
# [('ASDA Extra Special 6 Pork Sausages 400g',
#   'ASDA Extra Special 6 Cumberland Pork Sausages 400g',
#   '1',
#   '£2.25'),
#  ('ASDA Fat Free Natural Yogurt 500g',
#   'Arla Skyr Natural Yogurt 450g',
#   '1',
#   '£0.90'),
#  ('Birds Eye 2 Original Chicken Chargrills 170g',
#   'Birds Eye 2 Sweet & Sticky BBQ Chicken Chargrills 174g',
#   '1',
#   '£1.65'),
#  ('Warburtons 4 Bistro Brioche Burger Buns 4pk',
#   "Sheldon's Lancashire Oven Bottom Muffins 6pk",
#   '1',
#   '£1.00')]

# %% [markdown]
# We now want to obtain the unavailable items

# %%
# lines[i - 1] gives the unavailable item
# lines[i - 1][0] gives the first character which is the quantity
# lines[i + 1] gives the price

unavailable = []
for i in not_available_lines:
    unavailable.append((lines[i - 1][4:], lines[i - 1][0], lines[i + 1]))
    
unavailable
# Out:
# [('ASDA Plant Based Meat-Free Sausages 270g', '1', '£2.35'),
#  ('ASDA Cookies & Cream Celebration Cake each', '1', '£13.00')]

# %% [markdown]
# ### Creating ordered list
# Finally I want to created the ordered items list

# %%
ordered_start = lines.index('Your order')
ordered_end = lines.index('Groceries')

# %%
ordered = []
i = ordered_start + 1

while i < ordered_end:
    ordered.append(lines[i])
    i += 1

# %%
ordered
# Out:
# ['',
#  '',
#  'Fridge',
#  'Quantity',
#  'Price',
#  "ASDA Butcher's Selection 6 Thick Cut Smoked Back Bacon Rashers 300g",
#  '2',
#  '£3.38',
#  'ASDA Light Mozzarella Cheese 125g',
#  '1',
#  '£0.49',
#  'ASDA Halloumi 225g',
#  '1',
#  '£1.75',
#  'ASDA Sour Cream & Chive Dip 200g',
#  '1',
#  '£0.90',
#  "ASDA Butcher's Selection 8 Minted Lamb Kofta Kebabs 480g",
#  '1',
#  '£4.00',
#  "ASDA Butcher's Selection 4 BBQ Pork Kebabs 344g",
#  '1',
#  '£3.00',
#  'Cadbury Layers of Joy Chocolate Trifles 2x90g',
#  '1',
#  '£1.00',
#  "ASDA Grower's Selection Little Gem Lettuce 2pk",
#  '1',
#  '£0.65',
#  'ASDA Houmous 200g',
#  '1',
#  '£0.80',
#  "ASDA Grower's Selection Spring Onions each",
#  '1',
#  '£0.55',
#  'Apetina Classic Light Salad Cheese 200g',
#  '1',
#  '£1.00',
#  "ASDA Butcher's Selection Chicken Breast Fillets 650g",
#  '1',
#  '£3.40',
#  'ASDA Grated Mature Cheddar 250g',
#  '1',
#  '£1.75',
#  'ASDA Extra Special Baby Potatoes 1kg',
#  '1',
#  '£1.00',
#  'ASDA Extra Special 6 Pork & Caramelised Red Onion Sausages 400g',
#  '1',
#  '£2.25',
#  "ASDA Grower's Selection Cucumber each",
#  '1',
#  '£0.55',
#  'ASDA Extra Special 6 Lincolnshire Pork Sausages 400g',
#  '1',
#  '£2.25',
#  'Arla Skyr Natural Yogurt 450g',
#  '1',
#  '£1.25',
#  "ASDA Butcher's Selection Chinese Pork Loin Steaks 880g",
#  '1',
#  '£5.00',
#  'Lurpak Lighter Slightly Salted Spreadable 750g',
#  '1',
#  '£4.00',
#  "ASDA Grower's Selection Sweetcorn Cobettes 4pk",
#  '2',
#  '£2.00',
#  "ASDA Butcher's Selection Lean Beef Mince (Typically Less Than 5% Fat) 500g",
#  '2',
#  '£5.94',
#  'Others',
#  'Quantity',
#  'Price',
#  "ASDA Grower's Selection Loose Red Onion (order by number of onions or select kg) per kg",
#  '0.11kg',
#  '£0.09',
#  'Freezer',
#  'Quantity',
#  'Price',
#  'Toblerone Cheesecake 430g',
#  '1',
#  '£3.00',
#  'McCain Frozen Home Chips Straight 2.1kg',
#  '1',
#  '£3.00',
#  'Birds Eye 8 Crispy Battered Fish Fingers 224g',
#  '1',
#  '£1.58',
#  'ASDA Take Away BBQ Chicken & Bacon Stuffed Crust Pizza 458g',
#  '1',
#  '£2.00',
#  'ASDA 18 Battered Chicken Breast Chunks 350g',
#  '1',
#  '£2.50',
#  'Birds Eye 2 Original Chicken Chargrills 170g',
#  '1',
#  '£1.65',
#  'Fresh',
#  'Quantity',
#  'Price',
#  'ASDA White Pitta Breads 6pk',
#  '2',
#  '£0.90',
#  'Groceries, Health & Beauty and Household Items',
#  'Quantity',
#  'Price',
#  'Expert Grill 30cm Bamboo Skewers 100pk',
#  '1',
#  '£1.00',
#  'Birra Moretti Premium Lager 12x330',
#  '1',
#  '£12.00',
#  'ASDA 100% Pure Apple Juice Carton 1l',
#  '1',
#  '£0.65',
#  'Schweppes Slimline Lemonade 2lt',
#  '1',
#  '£1.00',
#  "ASDA Grower's Selection Mint 25g",
#  '1',
#  '£0.40',
#  "ASDA Grower's Selection Baby Plum Tomatoes 325g",
#  '1',
#  '£0.95',
#  "ASDA Grower's Selection Loose Lemon each",
#  '1',
#  '£0.30',
#  'Nishaan Plain Parathas 380g',
#  '1',
#  '£1.10',
#  'Napolina Italian Grated Cheese 80g',
#  '1',
#  '£1.89',
#  'ASDA 12 Large Free Range Eggs 12pk',
#  '1',
#  '£2.05',
#  'Douwe Egberts Pure Gold Medium Roast Instant Coffee 190g',
#  '1',
#  '£5.00',
#  'Batchelors Original Mushy Peas 3x300g',
#  '1',
#  '£1.40',
#  'Schweppes Lemonade 2lt',
#  '1',
#  '£1.00',
#  'ASDA Farm Stores Salad Tomatoes 6pk',
#  '1',
#  '£0.75',
#  'ASDA Pineapple Juice 1l',
#  '1',
#  '£0.80',
#  'Pepsi Max 2lt',
#  '2',
#  '£3.96',
#  'ASDA Lemon Juice from Concentrate 250ml',
#  '1',
#  '£0.39',
#  'ASDA White Basmati Rice 2kg',
#  '1',
#  '£2.89',
#  "ASDA Grower's Selection Sweet Peppers (Colour may vary) 3pk",
#  '1',
#  '£1.35',
#  'Belvita Breakfast Biscuits Soft Bakes Filled Choco Hazelnut 5 Pack 250g',
#  '1',
#  '£1.50',
#  'Belvita Breakfast Biscuits Cocoa with Choc Chips 5 Pack 225g',
#  '1',
#  '£1.00',
#  'ASDA No Added Sugar Double Strength Summer Fruits Squash 1.5l',
#  '1',
#  '£1.00',
#  'Popchips Sour Cream and Onion Sharing Crisps 85g',
#  '1',
#  '£1.00',
#  'ASDA Meatballs Pasta Sauce 500g',
#  '1',
#  '£0.79',
#  'Maggi So Tender Italian Herbs Chicken 23g',
#  '1',
#  '£0.75',
#  'Popchips Barbeque Sharing Crisps 85g',
#  '1',
#  '£1.00',
#  '',
#  '']

# %% [markdown]
# Now we want to remove blank linea and also the lines 'Quantity' and 'Price'

# %%
ordered = list(filter(remove_blank_and_headings, ordered))

# %%
ordered
# Out:
# ["ASDA Butcher's Selection 6 Thick Cut Smoked Back Bacon Rashers 300g",
#  '2',
#  '£3.38',
#  'ASDA Light Mozzarella Cheese 125g',
#  '1',
#  '£0.49',
#  'ASDA Halloumi 225g',
#  '1',
#  '£1.75',
#  'ASDA Sour Cream & Chive Dip 200g',
#  '1',
#  '£0.90',
#  "ASDA Butcher's Selection 8 Minted Lamb Kofta Kebabs 480g",
#  '1',
#  '£4.00',
#  "ASDA Butcher's Selection 4 BBQ Pork Kebabs 344g",
#  '1',
#  '£3.00',
#  'Cadbury Layers of Joy Chocolate Trifles 2x90g',
#  '1',
#  '£1.00',
#  "ASDA Grower's Selection Little Gem Lettuce 2pk",
#  '1',
#  '£0.65',
#  'ASDA Houmous 200g',
#  '1',
#  '£0.80',
#  "ASDA Grower's Selection Spring Onions each",
#  '1',
#  '£0.55',
#  'Apetina Classic Light Salad Cheese 200g',
#  '1',
#  '£1.00',
#  "ASDA Butcher's Selection Chicken Breast Fillets 650g",
#  '1',
#  '£3.40',
#  'ASDA Grated Mature Cheddar 250g',
#  '1',
#  '£1.75',
#  'ASDA Extra Special Baby Potatoes 1kg',
#  '1',
#  '£1.00',
#  'ASDA Extra Special 6 Pork & Caramelised Red Onion Sausages 400g',
#  '1',
#  '£2.25',
#  "ASDA Grower's Selection Cucumber each",
#  '1',
#  '£0.55',
#  'ASDA Extra Special 6 Lincolnshire Pork Sausages 400g',
#  '1',
#  '£2.25',
#  'Arla Skyr Natural Yogurt 450g',
#  '1',
#  '£1.25',
#  "ASDA Butcher's Selection Chinese Pork Loin Steaks 880g",
#  '1',
#  '£5.00',
#  'Lurpak Lighter Slightly Salted Spreadable 750g',
#  '1',
#  '£4.00',
#  "ASDA Grower's Selection Sweetcorn Cobettes 4pk",
#  '2',
#  '£2.00',
#  "ASDA Butcher's Selection Lean Beef Mince (Typically Less Than 5% Fat) 500g",
#  '2',
#  '£5.94',
#  "ASDA Grower's Selection Loose Red Onion (order by number of onions or select kg) per kg",
#  '0.11kg',
#  '£0.09',
#  'Toblerone Cheesecake 430g',
#  '1',
#  '£3.00',
#  'McCain Frozen Home Chips Straight 2.1kg',
#  '1',
#  '£3.00',
#  'Birds Eye 8 Crispy Battered Fish Fingers 224g',
#  '1',
#  '£1.58',
#  'ASDA Take Away BBQ Chicken & Bacon Stuffed Crust Pizza 458g',
#  '1',
#  '£2.00',
#  'ASDA 18 Battered Chicken Breast Chunks 350g',
#  '1',
#  '£2.50',
#  'Birds Eye 2 Original Chicken Chargrills 170g',
#  '1',
#  '£1.65',
#  'ASDA White Pitta Breads 6pk',
#  '2',
#  '£0.90',
#  'Expert Grill 30cm Bamboo Skewers 100pk',
#  '1',
#  '£1.00',
#  'Birra Moretti Premium Lager 12x330',
#  '1',
#  '£12.00',
#  'ASDA 100% Pure Apple Juice Carton 1l',
#  '1',
#  '£0.65',
#  'Schweppes Slimline Lemonade 2lt',
#  '1',
#  '£1.00',
#  "ASDA Grower's Selection Mint 25g",
#  '1',
#  '£0.40',
#  "ASDA Grower's Selection Baby Plum Tomatoes 325g",
#  '1',
#  '£0.95',
#  "ASDA Grower's Selection Loose Lemon each",
#  '1',
#  '£0.30',
#  'Nishaan Plain Parathas 380g',
#  '1',
#  '£1.10',
#  'Napolina Italian Grated Cheese 80g',
#  '1',
#  '£1.89',
#  'ASDA 12 Large Free Range Eggs 12pk',
#  '1',
#  '£2.05',
#  'Douwe Egberts Pure Gold Medium Roast Instant Coffee 190g',
#  '1',
#  '£5.00',
#  'Batchelors Original Mushy Peas 3x300g',
#  '1',
#  '£1.40',
#  'Schweppes Lemonade 2lt',
#  '1',
#  '£1.00',
#  'ASDA Farm Stores Salad Tomatoes 6pk',
#  '1',
#  '£0.75',
#  'ASDA Pineapple Juice 1l',
#  '1',
#  '£0.80',
#  'Pepsi Max 2lt',
#  '2',
#  '£3.96',
#  'ASDA Lemon Juice from Concentrate 250ml',
#  '1',
#  '£0.39',
#  'ASDA White Basmati Rice 2kg',
#  '1',
#  '£2.89',
#  "ASDA Grower's Selection Sweet Peppers (Colour may vary) 3pk",
#  '1',
#  '£1.35',
#  'Belvita Breakfast Biscuits Soft Bakes Filled Choco Hazelnut 5 Pack 250g',
#  '1',
#  '£1.50',
#  'Belvita Breakfast Biscuits Cocoa with Choc Chips 5 Pack 225g',
#  '1',
#  '£1.00',
#  'ASDA No Added Sugar Double Strength Summer Fruits Squash 1.5l',
#  '1',
#  '£1.00',
#  'Popchips Sour Cream and Onion Sharing Crisps 85g',
#  '1',
#  '£1.00',
#  'ASDA Meatballs Pasta Sauce 500g',
#  '1',
#  '£0.79',
#  'Maggi So Tender Italian Herbs Chicken 23g',
#  '1',
#  '£0.75',
#  'Popchips Barbeque Sharing Crisps 85g',
#  '1',
#  '£1.00']

# %%
# Create a list of tuples for the ordered items
i = 0
ordered_clean = []
print(len(ordered))

while i < len(ordered) :
    ordered_clean.append((ordered[i], ordered[i + 1], ordered[i + 2]))
    i += 3
    
print(ordered_clean)
# Out:
# 168
# [("ASDA Butcher's Selection 6 Thick Cut Smoked Back Bacon Rashers 300g", '2', '£3.38'), ('ASDA Light Mozzarella Cheese 125g', '1', '£0.49'), ('ASDA Halloumi 225g', '1', '£1.75'), ('ASDA Sour Cream & Chive Dip 200g', '1', '£0.90'), ("ASDA Butcher's Selection 8 Minted Lamb Kofta Kebabs 480g", '1', '£4.00'), ("ASDA Butcher's Selection 4 BBQ Pork Kebabs 344g", '1', '£3.00'), ('Cadbury Layers of Joy Chocolate Trifles 2x90g', '1', '£1.00'), ("ASDA Grower's Selection Little Gem Lettuce 2pk", '1', '£0.65'), ('ASDA Houmous 200g', '1', '£0.80'), ("ASDA Grower's Selection Spring Onions each", '1', '£0.55'), ('Apetina Classic Light Salad Cheese 200g', '1', '£1.00'), ("ASDA Butcher's Selection Chicken Breast Fillets 650g", '1', '£3.40'), ('ASDA Grated Mature Cheddar 250g', '1', '£1.75'), ('ASDA Extra Special Baby Potatoes 1kg', '1', '£1.00'), ('ASDA Extra Special 6 Pork & Caramelised Red Onion Sausages 400g', '1', '£2.25'), ("ASDA Grower's Selection Cucumber each", '1', '£0.55'), ('ASDA Extra Special 6 Lincolnshire Pork Sausages 400g', '1', '£2.25'), ('Arla Skyr Natural Yogurt 450g', '1', '£1.25'), ("ASDA Butcher's Selection Chinese Pork Loin Steaks 880g", '1', '£5.00'), ('Lurpak Lighter Slightly Salted Spreadable 750g', '1', '£4.00'), ("ASDA Grower's Selection Sweetcorn Cobettes 4pk", '2', '£2.00'), ("ASDA Butcher's Selection Lean Beef Mince (Typically Less Than 5% Fat) 500g", '2', '£5.94'), ("ASDA Grower's Selection Loose Red Onion (order by number of onions or select kg) per kg", '0.11kg', '£0.09'), ('Toblerone Cheesecake 430g', '1', '£3.00'), ('McCain Frozen Home Chips Straight 2.1kg', '1', '£3.00'), ('Birds Eye 8 Crispy Battered Fish Fingers 224g', '1', '£1.58'), ('ASDA Take Away BBQ Chicken & Bacon Stuffed Crust Pizza 458g', '1', '£2.00'), ('ASDA 18 Battered Chicken Breast Chunks 350g', '1', '£2.50'), ('Birds Eye 2 Original Chicken Chargrills 170g', '1', '£1.65'), ('ASDA White Pitta Breads 6pk', '2', '£0.90'), ('Expert Grill 30cm Bamboo Skewers 100pk', '1', '£1.00'), ('Birra Moretti Premium Lager 12x330', '1', '£12.00'), ('ASDA 100% Pure Apple Juice Carton 1l', '1', '£0.65'), ('Schweppes Slimline Lemonade 2lt', '1', '£1.00'), ("ASDA Grower's Selection Mint 25g", '1', '£0.40'), ("ASDA Grower's Selection Baby Plum Tomatoes 325g", '1', '£0.95'), ("ASDA Grower's Selection Loose Lemon each", '1', '£0.30'), ('Nishaan Plain Parathas 380g', '1', '£1.10'), ('Napolina Italian Grated Cheese 80g', '1', '£1.89'), ('ASDA 12 Large Free Range Eggs 12pk', '1', '£2.05'), ('Douwe Egberts Pure Gold Medium Roast Instant Coffee 190g', '1', '£5.00'), ('Batchelors Original Mushy Peas 3x300g', '1', '£1.40'), ('Schweppes Lemonade 2lt', '1', '£1.00'), ('ASDA Farm Stores Salad Tomatoes 6pk', '1', '£0.75'), ('ASDA Pineapple Juice 1l', '1', '£0.80'), ('Pepsi Max 2lt', '2', '£3.96'), ('ASDA Lemon Juice from Concentrate 250ml', '1', '£0.39'), ('ASDA White Basmati Rice 2kg', '1', '£2.89'), ("ASDA Grower's Selection Sweet Peppers (Colour may vary) 3pk", '1', '£1.35'), ('Belvita Breakfast Biscuits Soft Bakes Filled Choco Hazelnut 5 Pack 250g', '1', '£1.50'), ('Belvita Breakfast Biscuits Cocoa with Choc Chips 5 Pack 225g', '1', '£1.00'), ('ASDA No Added Sugar Double Strength Summer Fruits Squash 1.5l', '1', '£1.00'), ('Popchips Sour Cream and Onion Sharing Crisps 85g', '1', '£1.00'), ('ASDA Meatballs Pasta Sauce 500g', '1', '£0.79'), ('Maggi So Tender Italian Herbs Chicken 23g', '1', '£0.75'), ('Popchips Barbeque Sharing Crisps 85g', '1', '£1.00')]
